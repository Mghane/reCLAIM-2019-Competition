# %% [markdown]
# <a href="https://colab.research.google.com/github/Meisam-Heidari/reCLAIM-2019-Competition/blob/master/EDA_Meisam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#from google.colab import drive
#drive.mount('/gdrive')
#%cd /gdrive

# %% [markdown]
# # Classification DataSet

# %% [markdown]
# ## Loading

# %%
#df_clas_header_test = pd.read_csv("/gdrive/My Drive/reCLAIM 2019 Competition/classification_comp_starter_kit/classification_comp_starter_kit/Header - test.txt")
#df_clas_header_train = pd.read_csv("/gdrive/My Drive/reCLAIM 2019 Competition/classification_comp_starter_kit/classification_comp_starter_kit/Header - train.txt")
#df_clas_header_validation = pd.read_csv("/gdrive/My Drive/reCLAIM 2019 Competition/classification_comp_starter_kit/classification_comp_starter_kit/Header - validation.txt")
#df_clas_well_class_train = pd.read_csv("/gdrive/My Drive/reCLAIM 2019 Competition/classification_comp_starter_kit/classification_comp_starter_kit/Well_class_train.txt")
#df_clas_well_class_validation = pd.read_csv("/gdrive/My Drive/reCLAIM 2019 Competition/classification_comp_starter_kit/classification_comp_starter_kit/Well_class_validate.txt")

# %%
df_clas_header_test = pd.read_csv("classification/Header - test.txt")
df_clas_header_train = pd.read_csv("classification/Header - train.txt")
df_clas_header_validation = pd.read_csv("classification/Header - validation.txt")
df_clas_well_class_train = pd.read_csv("classification/Well_class_train.txt")
df_clas_well_class_validation = pd.read_csv("classification/Well_class_validate.txt")

# %%
df_clas_header_test.head(2)
# Out:
#    EPAssetsId Province LicenceNumber               UWI  \
# 0     2367432  Alberta       0195212  102032605705W400
# 1     2475476  Alberta       0264445  100023507714W400
#
#                       CurrentOperator  CurrentOperatorParent  \
# 0  Canadian Natural Resources Limited                    159
# 1  Canadian Natural Resources Limited                    159
#
#    CurrentOperatorID                            Licensee  \
# 0                NaN  Canadian Natural Resources Limited
# 1                NaN           Point Loma Resources Ltd.
#
#    LicenseeParentCompany  LicenseeID  ... UnitID UnitName UnitFlag  \
# 0                    159         NaN  ...    NaN      NaN       No
# 1                   8932         NaN  ...    NaN      NaN       No
#
#   Municipality CompletionDate        Agent _Max`Prod`(BOE) _Fracture`Stages  \
# 0          NaN            NaN  Unspecified             NaN              NaN
# 1          NaN            NaN  Unspecified             NaN              NaN
#
#        _Open`Hole _Completion`Events
# 0  CasedCompleted                NaN
# 1  CasedCompleted                NaN
#
# [2 rows x 90 columns]

# %%
df_clas_well_class_train.head(2)
# Out:
#    EPAssetsId well_status  well_status_code
# 0     2314251   Suspended                 2
# 1     2341273      Active                 1

# %%
df_clas_well_class_validation.head(2)
# Out:
#    EPAssetsId well_status  well_status_code
# 0           9   Suspended                 2
# 1          17      Active                 1

# %%
headers = []
for i in range(len(df_clas_header_train.columns)):
  headers.append([df_clas_header_train.columns[i],df_clas_header_validation.columns[i],df_clas_header_test.columns[i]])
headers
# Out:
# [['EPAssetsId', 'EPAssetsId', 'EPAssetsId'],
#  ['Province', 'Province', 'Province'],
#  ['LicenceNumber', 'LicenceNumber', 'LicenceNumber'],
#  ['UWI', 'UWI', 'UWI'],
#  ['CurrentOperator', 'CurrentOperator', 'CurrentOperator'],
#  ['CurrentOperatorParent', 'CurrentOperatorParent', 'CurrentOperatorParent'],
#  ['CurrentOperatorID', 'CurrentOperatorID', 'CurrentOperatorID'],
#  ['Licensee', 'Licensee', 'Licensee'],
#  ['LicenseeParentCompany', 'LicenseeParentCompany', 'LicenseeParentCompany'],
#  ['LicenseeID', 'LicenseeID', 'LicenseeID'],
#  ['LicenceDate', 'LicenceDate', 'LicenceDate'],
#  ['WellType', 'WellType', 'WellType'],
#  ['WellTypeStandardised', 'WellTypeStandardised', 'WellTypeStandardised'],
#  ['ConfidentialReleaseDate',
#   'ConfidentialReleaseDate',
#   'ConfidentialReleaseDate'],
#  ['SurfAbandonDate', 'SurfAbandonDate', 'SurfAbandonDate'],
#  ['WellName', 'WellName', 'WellName'],
#  ['WellNameAmended', 'WellNameAmended', 'WellNameAmended'],
#  ['Formation', 'Formation', 'Formation'],
#  ['Field', 'Field', 'Field'],
#  ['Pool', 'Pool', 'Pool'],
#  ['SurveySystem', 'SurveySystem', 'SurveySystem'],
#  ['Surf_Location', 'Surf_Location', 'Surf_Location'],
#  ['Surf_Township', 'Surf_Township', 'Surf_Township'],
#  ['Surf_Meridian', 'Surf_Meridian', 'Surf_Meridian'],
#  ['Surf_Range', 'Surf_Range', 'Surf_Range'],
#  ['Surf_Section', 'Surf_Section', 'Surf_Section'],
#  ['Surf_LSD', 'Surf_LSD', 'Surf_LSD'],
#  ['Surf_Longitude', 'Surf_Longitude', 'Surf_Longitude'],
#  ['Surf_Latitude', 'Surf_Latitude', 'Surf_Latitude'],
#  ['Surf_TownshipRange', 'Surf_TownshipRange', 'Surf_TownshipRange'],
#  ['Surf_QuarterUnit', 'Surf_QuarterUnit', 'Surf_QuarterUnit'],
#  ['Surf_Unit', 'Surf_Unit', 'Surf_Unit'],
#  ['Surf_Block', 'Surf_Block', 'Surf_Block'],
#  ['Surf_NTSMapSheet', 'Surf_NTSMapSheet', 'Surf_NTSMapSheet'],
#  ['Surf_Series', 'Surf_Series', 'Surf_Series'],
#  ['Surf_Area', 'Surf_Area', 'Surf_Area'],
#  ['Surf_Sheet', 'Surf_Sheet', 'Surf_Sheet'],
#  ['Surf_QuarterSection', 'Surf_QuarterSection', 'Surf_QuarterSection'],
#  ['BH_Location', 'BH_Location', 'BH_Location'],
#  ['BH_TownshipRange', 'BH_TownshipRange', 'BH_TownshipRange'],
#  ['BH_QuarterUnit', 'BH_QuarterUnit', 'BH_QuarterUnit'],
#  ['BH_Unit', 'BH_Unit', 'BH_Unit'],
#  ['BH_Block', 'BH_Block', 'BH_Block'],
#  ['BH_NTSMapSheet', 'BH_NTSMapSheet', 'BH_NTSMapSheet'],
#  ['BH_Series', 'BH_Series', 'BH_Series'],
#  ['BH_Area', 'BH_Area', 'BH_Area'],
#  ['BH_Sheet', 'BH_Sheet', 'BH_Sheet'],
#  ['BH_QuarterSection', 'BH_QuarterSection', 'BH_QuarterSection'],
#  ['BH_Longitude', 'BH_Longitude', 'BH_Longitude'],
#  ['BH_Latitude', 'BH_Latitude', 'BH_Latitude'],
#  ['BH_Township', 'BH_Township', 'BH_Township'],
#  ['BH_Meridian', 'BH_Meridian', 'BH_Meridian'],
#  ['BH_Range', 'BH_Range', 'BH_Range'],
#  ['BH_Section', 'BH_Section', 'BH_Section'],
#  ['BH_LSD', 'BH_LSD', 'BH_LSD'],
#  ['GroundElevation', 'GroundElevation', 'GroundElevation'],
#  ['KBElevation', 'KBElevation', 'KBElevation'],
#  ['TotalDepth', 'TotalDepth', 'TotalDepth'],
#  ['LaheeClass', 'LaheeClass', 'LaheeClass'],
#  ['Confidential', 'Confidential', 'Confidential'],
#  ['SurfaceOwner', 'SurfaceOwner', 'SurfaceOwner'],
#  ['OSArea', 'OSArea', 'OSArea'],
#  ['OSDeposit', 'OSDeposit', 'OSDeposit'],
#  ['DrillingContractor', 'DrillingContractor', 'DrillingContractor'],
#  ['SpudDate', 'SpudDate', 'SpudDate'],
#  ['FinalDrillDate', 'FinalDrillDate', 'FinalDrillDate'],
#  ['RigReleaseDate', 'RigReleaseDate', 'RigReleaseDate'],
#  ['DaysDrilling', 'DaysDrilling', 'DaysDrilling'],
#  ['DrillMetresPerDay', 'DrillMetresPerDay', 'DrillMetresPerDay'],
#  ['TVD', 'TVD', 'TVD'],
#  ['WellProfile', 'WellProfile', 'WellProfile'],
#  ['WellSymbPt1', 'WellSymbPt1', 'WellSymbPt1'],
#  ['Country', 'Country', 'Country'],
#  ['RegulatoryAgency', 'RegulatoryAgency', 'RegulatoryAgency'],
#  ['NumberofWells', 'NumberofWells', 'NumberofWells'],
#  ['PSACAreaCode', 'PSACAreaCode', 'PSACAreaCode'],
#  ['PSACAreaName', 'PSACAreaName', 'PSACAreaName'],
#  ['ProjectedDepth', 'ProjectedDepth', 'ProjectedDepth'],
#  ['StatusDate', 'StatusDate', 'StatusDate'],
#  ['StatusSource', 'StatusSource', 'StatusSource'],
#  ['UnitID', 'UnitID', 'UnitID'],
#  ['UnitName', 'UnitName', 'UnitName'],
#  ['UnitFlag', 'UnitFlag', 'UnitFlag'],
#  ['Municipality', 'Municipality', 'Municipality'],
#  ['CompletionDate', 'CompletionDate', 'CompletionDate'],
#  ['Agent', 'Agent', 'Agent'],
#  ['_Max`Prod`(BOE)', '_Max`Prod`(BOE)', '_Max`Prod`(BOE)'],
#  ['_Fracture`Stages', '_Fracture`Stages', '_Fracture`Stages'],
#  ['_Open`Hole', '_Open`Hole', '_Open`Hole'],
#  ['_Completion`Events', '_Completion`Events', '_Completion`Events']]

# %% [markdown]
# ## Header Test file

# %%
df_clas_header_test.shape
# Out:
# (118076, 90)

# %%
df_clas_header_test.nunique()
# Out:
# EPAssetsId            118076
# Province                   4
# LicenceNumber         112547
# UWI                   116725
# CurrentOperator          860
#                        ...
# Agent                    356
# _Max`Prod`(BOE)        21636
# _Fracture`Stages          89
# _Open`Hole                 2
# _Completion`Events       174
# Length: 90, dtype: int64

# %%
df_clas_header_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118076 entries, 0 to 118075
# Data columns (total 90 columns):
# EPAssetsId                 118076 non-null int64
# Province                   118076 non-null object
# LicenceNumber              118076 non-null object
# UWI                        118076 non-null object
# CurrentOperator            118076 non-null object
# CurrentOperatorParent      118076 non-null int64
# CurrentOperatorID          25138 non-null float64
# Licensee                   118076 non-null object
# LicenseeParentCompany      118076 non-null int64
# LicenseeID                 1667 non-null float64
# LicenceDate                118074 non-null object
# WellType                   118076 non-null object
# WellTypeStandardised       118076 non-null object
# ConfidentialReleaseDate    62998 non-null object
# SurfAbandonDate            26822 non-null object
# WellName                   117976 non-null object
# WellNameAmended            117976 non-null object
# Formation                  118076 non-null object
# Field                      118076 non-null object
# Pool                       118031 non-null object
# SurveySystem               118076 non-null object
# Surf_Location              118014 non-null object
# Surf_Township              118076 non-null object
# Surf_Meridian              118076 non-null object
# Surf_Range                 118076 non-null object
# Surf_Section               118076 non-null object
# Surf_LSD                   118076 non-null object
# Surf_Longitude             118076 non-null float64
# Surf_Latitude              118075 non-null float64
# Surf_TownshipRange         118076 non-null object
# Surf_QuarterUnit           118076 non-null object
# Surf_Unit                  118076 non-null object
# Surf_Block                 118076 non-null object
# Surf_NTSMapSheet           118076 non-null object
# Surf_Series                118076 non-null object
# Surf_Area                  118076 non-null object
# Surf_Sheet                 118076 non-null object
# Surf_QuarterSection        118076 non-null object
# BH_Location                118076 non-null object
# BH_TownshipRange           118076 non-null object
# BH_QuarterUnit             118075 non-null object
# BH_Unit                    118075 non-null object
# BH_Block                   118075 non-null object
# BH_NTSMapSheet             118076 non-null object
# BH_Series                  118075 non-null object
# BH_Area                    118075 non-null object
# BH_Sheet                   118075 non-null object
# BH_QuarterSection          111761 non-null object
# BH_Longitude               111198 non-null float64
# BH_Latitude                111198 non-null float64
# BH_Township                118074 non-null object
# BH_Meridian                118076 non-null object
# BH_Range                   118074 non-null object
# BH_Section                 118074 non-null object
# BH_LSD                     118074 non-null object
# GroundElevation            118017 non-null float64
# KBElevation                116054 non-null float64
# TotalDepth                 116727 non-null float64
# LaheeClass                 118076 non-null object
# Confidential               118076 non-null object
# SurfaceOwner               115971 non-null object
# OSArea                     111582 non-null object
# OSDeposit                  111582 non-null object
# DrillingContractor         117733 non-null object
# SpudDate                   113070 non-null object
# FinalDrillDate             107921 non-null object
# RigReleaseDate             95545 non-null object
# DaysDrilling               112785 non-null float64
# DrillMetresPerDay          118070 non-null float64
# TVD                        110450 non-null float64
# WellProfile                118076 non-null object
# WellSymbPt1                118076 non-null object
# Country                    118076 non-null object
# RegulatoryAgency           118076 non-null object
# NumberofWells              118076 non-null int64
# PSACAreaCode               118076 non-null object
# PSACAreaName               118076 non-null object
# ProjectedDepth             84586 non-null float64
# StatusDate                 118057 non-null object
# StatusSource               118076 non-null object
# UnitID                     9312 non-null object
# UnitName                   9312 non-null object
# UnitFlag                   111537 non-null object
# Municipality               24326 non-null object
# CompletionDate             23871 non-null object
# Agent                      118076 non-null object
# _Max`Prod`(BOE)            40188 non-null float64
# _Fracture`Stages           1595 non-null float64
# _Open`Hole                 118076 non-null object
# _Completion`Events         3422 non-null float64
# dtypes: float64(16), int64(4), object(70)
# memory usage: 81.1+ MB

# %% [markdown]
# ## Header Validation File

# %%
df_clas_header_validation.shape
# Out:
# (132131, 90)

# %%
df_clas_header_validation.nunique()
# Out:
# EPAssetsId            132131
# Province                   4
# LicenceNumber         125962
# UWI                   130765
# CurrentOperator          913
#                        ...
# Agent                    439
# _Max`Prod`(BOE)        21560
# _Fracture`Stages          86
# _Open`Hole                 2
# _Completion`Events       170
# Length: 90, dtype: int64

# %%
df_clas_header_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132131 entries, 0 to 132130
# Data columns (total 90 columns):
# EPAssetsId                 132131 non-null int64
# Province                   132131 non-null object
# LicenceNumber              132131 non-null object
# UWI                        132130 non-null object
# CurrentOperator            132131 non-null object
# CurrentOperatorParent      132131 non-null int64
# CurrentOperatorID          27993 non-null float64
# Licensee                   132131 non-null object
# LicenseeParentCompany      132131 non-null int64
# LicenseeID                 2031 non-null float64
# LicenceDate                132126 non-null object
# WellType                   132131 non-null object
# WellTypeStandardised       132131 non-null object
# ConfidentialReleaseDate    69272 non-null object
# SurfAbandonDate            35942 non-null object
# WellName                   132034 non-null object
# WellNameAmended            132034 non-null object
# Formation                  132131 non-null object
# Field                      132131 non-null object
# Pool                       132086 non-null object
# SurveySystem               132131 non-null object
# Surf_Location              132066 non-null object
# Surf_Township              132131 non-null object
# Surf_Meridian              132131 non-null object
# Surf_Range                 132131 non-null object
# Surf_Section               132131 non-null object
# Surf_LSD                   132131 non-null object
# Surf_Longitude             132131 non-null float64
# Surf_Latitude              132131 non-null float64
# Surf_TownshipRange         132131 non-null object
# Surf_QuarterUnit           132131 non-null object
# Surf_Unit                  132131 non-null object
# Surf_Block                 132131 non-null object
# Surf_NTSMapSheet           132131 non-null object
# Surf_Series                132131 non-null object
# Surf_Area                  132131 non-null object
# Surf_Sheet                 132131 non-null object
# Surf_QuarterSection        132131 non-null object
# BH_Location                132131 non-null object
# BH_TownshipRange           132131 non-null object
# BH_QuarterUnit             132131 non-null object
# BH_Unit                    132131 non-null object
# BH_Block                   132131 non-null object
# BH_NTSMapSheet             132131 non-null object
# BH_Series                  132131 non-null object
# BH_Area                    132131 non-null object
# BH_Sheet                   132131 non-null object
# BH_QuarterSection          125660 non-null object
# BH_Longitude               125082 non-null float64
# BH_Latitude                125082 non-null float64
# BH_Township                132130 non-null object
# BH_Meridian                132130 non-null object
# BH_Range                   132130 non-null object
# BH_Section                 132130 non-null object
# BH_LSD                     132130 non-null object
# GroundElevation            132063 non-null float64
# KBElevation                130049 non-null float64
# TotalDepth                 130804 non-null float64
# LaheeClass                 132131 non-null object
# Confidential               132131 non-null object
# SurfaceOwner               129623 non-null object
# OSArea                     125492 non-null object
# OSDeposit                  125492 non-null object
# DrillingContractor         131793 non-null object
# SpudDate                   126993 non-null object
# FinalDrillDate             121664 non-null object
# RigReleaseDate             103043 non-null object
# DaysDrilling               126724 non-null float64
# DrillMetresPerDay          132123 non-null float64
# TVD                        124373 non-null float64
# WellProfile                132131 non-null object
# WellSymbPt1                132131 non-null object
# Country                    132131 non-null object
# RegulatoryAgency           132131 non-null object
# NumberofWells              132131 non-null int64
# PSACAreaCode               132131 non-null object
# PSACAreaName               132131 non-null object
# ProjectedDepth             88458 non-null float64
# StatusDate                 132108 non-null object
# StatusSource               132131 non-null object
# UnitID                     9794 non-null object
# UnitName                   9794 non-null object
# UnitFlag                   125445 non-null object
# Municipality               25908 non-null object
# CompletionDate             24530 non-null object
# Agent                      132131 non-null object
# _Max`Prod`(BOE)            40211 non-null float64
# _Fracture`Stages           1630 non-null float64
# _Open`Hole                 132131 non-null object
# _Completion`Events         3487 non-null float64
# dtypes: float64(16), int64(4), object(70)
# memory usage: 90.7+ MB

# %% [markdown]
# ## Header train File

# %%
df_clas_header_train.shape
# Out:
# (588673, 90)

# %%
df_clas_header_train.nunique()
# Out:
# EPAssetsId            588673
# Province                   4
# LicenceNumber         485571
# UWI                   582171
# CurrentOperator         1468
#                        ...
# Agent                    929
# _Max`Prod`(BOE)        86073
# _Fracture`Stages         131
# _Open`Hole                 2
# _Completion`Events       305
# Length: 90, dtype: int64

# %%
df_clas_header_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588673 entries, 0 to 588672
# Data columns (total 90 columns):
# EPAssetsId                 588673 non-null int64
# Province                   588673 non-null object
# LicenceNumber              588673 non-null object
# UWI                        588673 non-null object
# CurrentOperator            588673 non-null object
# CurrentOperatorParent      588673 non-null int64
# CurrentOperatorID          124038 non-null float64
# Licensee                   588673 non-null object
# LicenseeParentCompany      588673 non-null int64
# LicenseeID                 8537 non-null float64
# LicenceDate                588664 non-null object
# WellType                   588673 non-null object
# WellTypeStandardised       588673 non-null object
# ConfidentialReleaseDate    310703 non-null object
# SurfAbandonDate            149148 non-null object
# WellName                   588206 non-null object
# WellNameAmended            588206 non-null object
# Formation                  588673 non-null object
# Field                      588673 non-null object
# Pool                       588442 non-null object
# SurveySystem               588673 non-null object
# Surf_Location              588366 non-null object
# Surf_Township              588673 non-null object
# Surf_Meridian              588673 non-null object
# Surf_Range                 588673 non-null object
# Surf_Section               588673 non-null object
# Surf_LSD                   588673 non-null object
# Surf_Longitude             588673 non-null float64
# Surf_Latitude              588673 non-null float64
# Surf_TownshipRange         588673 non-null object
# Surf_QuarterUnit           588673 non-null object
# Surf_Unit                  588673 non-null object
# Surf_Block                 588673 non-null object
# Surf_NTSMapSheet           588673 non-null object
# Surf_Series                588673 non-null object
# Surf_Area                  588673 non-null object
# Surf_Sheet                 588673 non-null object
# Surf_QuarterSection        588673 non-null object
# BH_Location                588673 non-null object
# BH_TownshipRange           588673 non-null object
# BH_QuarterUnit             588673 non-null object
# BH_Unit                    588673 non-null object
# BH_Block                   588673 non-null object
# BH_NTSMapSheet             588673 non-null object
# BH_Series                  588673 non-null object
# BH_Area                    588673 non-null object
# BH_Sheet                   588673 non-null object
# BH_QuarterSection          558395 non-null object
# BH_Longitude               555782 non-null float64
# BH_Latitude                555782 non-null float64
# BH_Township                588668 non-null object
# BH_Meridian                588673 non-null object
# BH_Range                   588668 non-null object
# BH_Section                 588668 non-null object
# BH_LSD                     588668 non-null object
# GroundElevation            588371 non-null float64
# KBElevation                579272 non-null float64
# TotalDepth                 582541 non-null float64
# LaheeClass                 588673 non-null object
# Confidential               588673 non-null object
# SurfaceOwner               577873 non-null object
# OSArea                     557634 non-null object
# OSDeposit                  557634 non-null object
# DrillingContractor         587108 non-null object
# SpudDate                   564917 non-null object
# FinalDrillDate             540114 non-null object
# RigReleaseDate             465455 non-null object
# DaysDrilling               563617 non-null float64
# DrillMetresPerDay          588630 non-null float64
# TVD                        552435 non-null float64
# WellProfile                588673 non-null object
# WellSymbPt1                588673 non-null object
# Country                    588673 non-null object
# RegulatoryAgency           588673 non-null object
# NumberofWells              588673 non-null int64
# PSACAreaCode               588673 non-null object
# PSACAreaName               588673 non-null object
# ProjectedDepth             404812 non-null float64
# StatusDate                 588603 non-null object
# StatusSource               588673 non-null object
# UnitID                     44299 non-null object
# UnitName                   44299 non-null object
# UnitFlag                   557380 non-null object
# Municipality               116651 non-null object
# CompletionDate             113144 non-null object
# Agent                      588673 non-null object
# _Max`Prod`(BOE)            187602 non-null float64
# _Fracture`Stages           7685 non-null float64
# _Open`Hole                 588673 non-null object
# _Completion`Events         16329 non-null float64
# dtypes: float64(16), int64(4), object(70)
# memory usage: 404.2+ MB

# %% [markdown]
# ## Well class train File

# %%
df_clas_well_class_train.shape
# Out:
# (588673, 3)

# %%
df_clas_well_class_train.nunique()
# Out:
# EPAssetsId          588673
# well_status              3
# well_status_code         3
# dtype: int64

# %%
df_clas_well_class_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 588673 entries, 0 to 588672
# Data columns (total 3 columns):
# EPAssetsId          588673 non-null int64
# well_status         588673 non-null object
# well_status_code    588673 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 13.5+ MB

# %%
df_clas_well_class_train.head()
# Out:
#    EPAssetsId well_status  well_status_code
# 0     2314251   Suspended                 2
# 1     2341273      Active                 1
# 2     1086314   Abandoned                 0
# 3     2210835   Abandoned                 0
# 4       40946   Suspended                 2

# %%
df_clas_well_class_train.describe()
# Out:
#          EPAssetsId  well_status_code
# count  5.886730e+05     588673.000000
# mean   2.019055e+06          0.759097
# std    9.069427e+05          0.737610
# min    1.000000e+00          0.000000
# 25%    2.001535e+06          0.000000
# 50%    2.210924e+06          1.000000
# 75%    2.420443e+06          1.000000
# max    7.012320e+06          2.000000

# %% [markdown]
# ## Well Class Validation File

# %%
df_clas_well_class_validation.shape
# Out:
# (132131, 3)

# %%
df_clas_well_class_validation.nunique()
# Out:
# EPAssetsId          132131
# well_status              3
# well_status_code         3
# dtype: int64

# %%
df_clas_well_class_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132131 entries, 0 to 132130
# Data columns (total 3 columns):
# EPAssetsId          132131 non-null int64
# well_status         132131 non-null object
# well_status_code    132131 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 3.0+ MB

# %%
df_clas_well_class_validation.head()
# Out:
#    EPAssetsId well_status  well_status_code
# 0           9   Suspended                 2
# 1          17      Active                 1
# 2          23   Abandoned                 0
# 3          37      Active                 1
# 4          39      Active                 1

# %%
df_clas_well_class_validation.describe()
# Out:
#          EPAssetsId  well_status_code
# count  1.321310e+05     132131.000000
# mean   2.028815e+06          0.724955
# std    9.144068e+05          0.738822
# min    9.000000e+00          0.000000
# 25%    2.003216e+06          0.000000
# 50%    2.215400e+06          1.000000
# 75%    2.422774e+06          1.000000
# max    7.012319e+06          2.000000

# %% [markdown]
# # Merge Data

# %%
df_clas_well_class_train['EPAssetsId'].duplicated().sum(), df_clas_header_train['EPAssetsId'].duplicated().sum()
# Out:
# (0, 0)

# %%
df_train = pd.merge(df_clas_well_class_train, df_clas_header_train, on = ['EPAssetsId','EPAssetsId'] )

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588673 entries, 0 to 588672
# Data columns (total 92 columns):
# EPAssetsId                 588673 non-null int64
# well_status                588673 non-null object
# well_status_code           588673 non-null int64
# Province                   588673 non-null object
# LicenceNumber              588673 non-null object
# UWI                        588673 non-null object
# CurrentOperator            588673 non-null object
# CurrentOperatorParent      588673 non-null int64
# CurrentOperatorID          124038 non-null float64
# Licensee                   588673 non-null object
# LicenseeParentCompany      588673 non-null int64
# LicenseeID                 8537 non-null float64
# LicenceDate                588664 non-null object
# WellType                   588673 non-null object
# WellTypeStandardised       588673 non-null object
# ConfidentialReleaseDate    310703 non-null object
# SurfAbandonDate            149148 non-null object
# WellName                   588206 non-null object
# WellNameAmended            588206 non-null object
# Formation                  588673 non-null object
# Field                      588673 non-null object
# Pool                       588442 non-null object
# SurveySystem               588673 non-null object
# Surf_Location              588366 non-null object
# Surf_Township              588673 non-null object
# Surf_Meridian              588673 non-null object
# Surf_Range                 588673 non-null object
# Surf_Section               588673 non-null object
# Surf_LSD                   588673 non-null object
# Surf_Longitude             588673 non-null float64
# Surf_Latitude              588673 non-null float64
# Surf_TownshipRange         588673 non-null object
# Surf_QuarterUnit           588673 non-null object
# Surf_Unit                  588673 non-null object
# Surf_Block                 588673 non-null object
# Surf_NTSMapSheet           588673 non-null object
# Surf_Series                588673 non-null object
# Surf_Area                  588673 non-null object
# Surf_Sheet                 588673 non-null object
# Surf_QuarterSection        588673 non-null object
# BH_Location                588673 non-null object
# BH_TownshipRange           588673 non-null object
# BH_QuarterUnit             588673 non-null object
# BH_Unit                    588673 non-null object
# BH_Block                   588673 non-null object
# BH_NTSMapSheet             588673 non-null object
# BH_Series                  588673 non-null object
# BH_Area                    588673 non-null object
# BH_Sheet                   588673 non-null object
# BH_QuarterSection          558395 non-null object
# BH_Longitude               555782 non-null float64
# BH_Latitude                555782 non-null float64
# BH_Township                588668 non-null object
# BH_Meridian                588673 non-null object
# BH_Range                   588668 non-null object
# BH_Section                 588668 non-null object
# BH_LSD                     588668 non-null object
# GroundElevation            588371 non-null float64
# KBElevation                579272 non-null float64
# TotalDepth                 582541 non-null float64
# LaheeClass                 588673 non-null object
# Confidential               588673 non-null object
# SurfaceOwner               577873 non-null object
# OSArea                     557634 non-null object
# OSDeposit                  557634 non-null object
# DrillingContractor         587108 non-null object
# SpudDate                   564917 non-null object
# FinalDrillDate             540114 non-null object
# RigReleaseDate             465455 non-null object
# DaysDrilling               563617 non-null float64
# DrillMetresPerDay          588630 non-null float64
# TVD                        552435 non-null float64
# WellProfile                588673 non-null object
# WellSymbPt1                588673 non-null object
# Country                    588673 non-null object
# RegulatoryAgency           588673 non-null object
# NumberofWells              588673 non-null int64
# PSACAreaCode               588673 non-null object
# PSACAreaName               588673 non-null object
# ProjectedDepth             404812 non-null float64
# StatusDate                 588603 non-null object
# StatusSource               588673 non-null object
# UnitID                     44299 non-null object
# UnitName                   44299 non-null object
# UnitFlag                   557380 non-null object
# Municipality               116651 non-null object
# CompletionDate             113144 non-null object
# Agent                      588673 non-null object
# _Max`Prod`(BOE)            187602 non-null float64
# _Fracture`Stages           7685 non-null float64
# _Open`Hole                 588673 non-null object
# _Completion`Events         16329 non-null float64
# dtypes: float64(16), int64(5), object(71)
# memory usage: 417.7+ MB

# %%
df_clas_well_class_validation['EPAssetsId'].duplicated().sum(), df_clas_header_validation['EPAssetsId'].duplicated().sum()
# Out:
# (0, 0)

# %%
df_validation = pd.merge(df_clas_well_class_validation, df_clas_header_validation, on = ['EPAssetsId','EPAssetsId'] )

# %%
df_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132131 entries, 0 to 132130
# Data columns (total 92 columns):
# EPAssetsId                 132131 non-null int64
# well_status                132131 non-null object
# well_status_code           132131 non-null int64
# Province                   132131 non-null object
# LicenceNumber              132131 non-null object
# UWI                        132130 non-null object
# CurrentOperator            132131 non-null object
# CurrentOperatorParent      132131 non-null int64
# CurrentOperatorID          27993 non-null float64
# Licensee                   132131 non-null object
# LicenseeParentCompany      132131 non-null int64
# LicenseeID                 2031 non-null float64
# LicenceDate                132126 non-null object
# WellType                   132131 non-null object
# WellTypeStandardised       132131 non-null object
# ConfidentialReleaseDate    69272 non-null object
# SurfAbandonDate            35942 non-null object
# WellName                   132034 non-null object
# WellNameAmended            132034 non-null object
# Formation                  132131 non-null object
# Field                      132131 non-null object
# Pool                       132086 non-null object
# SurveySystem               132131 non-null object
# Surf_Location              132066 non-null object
# Surf_Township              132131 non-null object
# Surf_Meridian              132131 non-null object
# Surf_Range                 132131 non-null object
# Surf_Section               132131 non-null object
# Surf_LSD                   132131 non-null object
# Surf_Longitude             132131 non-null float64
# Surf_Latitude              132131 non-null float64
# Surf_TownshipRange         132131 non-null object
# Surf_QuarterUnit           132131 non-null object
# Surf_Unit                  132131 non-null object
# Surf_Block                 132131 non-null object
# Surf_NTSMapSheet           132131 non-null object
# Surf_Series                132131 non-null object
# Surf_Area                  132131 non-null object
# Surf_Sheet                 132131 non-null object
# Surf_QuarterSection        132131 non-null object
# BH_Location                132131 non-null object
# BH_TownshipRange           132131 non-null object
# BH_QuarterUnit             132131 non-null object
# BH_Unit                    132131 non-null object
# BH_Block                   132131 non-null object
# BH_NTSMapSheet             132131 non-null object
# BH_Series                  132131 non-null object
# BH_Area                    132131 non-null object
# BH_Sheet                   132131 non-null object
# BH_QuarterSection          125660 non-null object
# BH_Longitude               125082 non-null float64
# BH_Latitude                125082 non-null float64
# BH_Township                132130 non-null object
# BH_Meridian                132130 non-null object
# BH_Range                   132130 non-null object
# BH_Section                 132130 non-null object
# BH_LSD                     132130 non-null object
# GroundElevation            132063 non-null float64
# KBElevation                130049 non-null float64
# TotalDepth                 130804 non-null float64
# LaheeClass                 132131 non-null object
# Confidential               132131 non-null object
# SurfaceOwner               129623 non-null object
# OSArea                     125492 non-null object
# OSDeposit                  125492 non-null object
# DrillingContractor         131793 non-null object
# SpudDate                   126993 non-null object
# FinalDrillDate             121664 non-null object
# RigReleaseDate             103043 non-null object
# DaysDrilling               126724 non-null float64
# DrillMetresPerDay          132123 non-null float64
# TVD                        124373 non-null float64
# WellProfile                132131 non-null object
# WellSymbPt1                132131 non-null object
# Country                    132131 non-null object
# RegulatoryAgency           132131 non-null object
# NumberofWells              132131 non-null int64
# PSACAreaCode               132131 non-null object
# PSACAreaName               132131 non-null object
# ProjectedDepth             88458 non-null float64
# StatusDate                 132108 non-null object
# StatusSource               132131 non-null object
# UnitID                     9794 non-null object
# UnitName                   9794 non-null object
# UnitFlag                   125445 non-null object
# Municipality               25908 non-null object
# CompletionDate             24530 non-null object
# Agent                      132131 non-null object
# _Max`Prod`(BOE)            40211 non-null float64
# _Fracture`Stages           1630 non-null float64
# _Open`Hole                 132131 non-null object
# _Completion`Events         3487 non-null float64
# dtypes: float64(16), int64(5), object(71)
# memory usage: 93.8+ MB

# %%
# Basic EDA

# %% [markdown]
# # Feature Engineering
# - Correlation
# - Score Gain
# - ?

# %%
features_lst = list(df_train.columns)
len(features_lst)
# Out:
# 92

# %%
corr = df_train.corr()
plt.figure(figsize=(9,7))
sns.heatmap(
    corr,
    xticklabels=corr.columns.values,
    yticklabels=corr.columns.values,
    linecolor='white',
    linewidths=0.1,
    cmap="RdBu"
)
plt.show()

# %%
corr[corr>0.5]
# Out:
#                        EPAssetsId  well_status_code  CurrentOperatorParent  \
# EPAssetsId                    1.0               NaN                    NaN
# well_status_code              NaN               1.0                    NaN
# CurrentOperatorParent         NaN               NaN               1.000000
# CurrentOperatorID             NaN               NaN                    NaN
# LicenseeParentCompany         NaN               NaN               0.702048
# LicenseeID                    NaN               NaN                    NaN
# Surf_Longitude                NaN               NaN                    NaN
# Surf_Latitude                 NaN               NaN                    NaN
# BH_Longitude                  NaN               NaN                    NaN
# BH_Latitude                   NaN               NaN                    NaN
# GroundElevation               NaN               NaN                    NaN
# KBElevation                   NaN               NaN                    NaN
# TotalDepth                    NaN               NaN                    NaN
# DaysDrilling                  NaN               NaN                    NaN
# DrillMetresPerDay             NaN               NaN                    NaN
# TVD                           NaN               NaN                    NaN
# NumberofWells                 NaN               NaN                    NaN
# ProjectedDepth                NaN               NaN                    NaN
# _Max`Prod`(BOE)               NaN               NaN                    NaN
# _Fracture`Stages              NaN               NaN                    NaN
# _Completion`Events            NaN               NaN                    NaN
#
#                        CurrentOperatorID  LicenseeParentCompany  LicenseeID  \
# EPAssetsId                           NaN                    NaN         NaN
# well_status_code                     NaN                    NaN         NaN
# CurrentOperatorParent                NaN               0.702048         NaN
# CurrentOperatorID               1.000000                    NaN    0.999369
# LicenseeParentCompany                NaN               1.000000         NaN
# LicenseeID                      0.999369                    NaN    1.000000
# Surf_Longitude                       NaN                    NaN         NaN
# Surf_Latitude                        NaN                    NaN         NaN
# BH_Longitude                         NaN                    NaN         NaN
# BH_Latitude                          NaN                    NaN         NaN
# GroundElevation                      NaN                    NaN         NaN
# KBElevation                          NaN                    NaN         NaN
# TotalDepth                           NaN                    NaN         NaN
# DaysDrilling                         NaN                    NaN         NaN
# DrillMetresPerDay                    NaN                    NaN         NaN
# TVD                                  NaN                    NaN         NaN
# NumberofWells                        NaN                    NaN         NaN
# ProjectedDepth                       NaN                    NaN         NaN
# _Max`Prod`(BOE)                      NaN                    NaN         NaN
# _Fracture`Stages                     NaN                    NaN         NaN
# _Completion`Events                   NaN                    NaN         NaN
#
#                        Surf_Longitude  Surf_Latitude  BH_Longitude  \
# EPAssetsId                        NaN            NaN           NaN
# well_status_code                  NaN            NaN           NaN
# CurrentOperatorParent             NaN            NaN           NaN
# CurrentOperatorID                 NaN            NaN           NaN
# LicenseeParentCompany             NaN            NaN           NaN
# LicenseeID                        NaN            NaN           NaN
# Surf_Longitude               1.000000            NaN      0.829301
# Surf_Latitude                     NaN       1.000000           NaN
# BH_Longitude                 0.829301            NaN      1.000000
# BH_Latitude                       NaN       0.865559           NaN
# GroundElevation                   NaN            NaN           NaN
# KBElevation                       NaN            NaN           NaN
# TotalDepth                        NaN            NaN           NaN
# DaysDrilling                      NaN            NaN           NaN
# DrillMetresPerDay                 NaN            NaN           NaN
# TVD                               NaN            NaN           NaN
# NumberofWells                     NaN            NaN           NaN
# ProjectedDepth                    NaN            NaN           NaN
# _Max`Prod`(BOE)                   NaN            NaN           NaN
# _Fracture`Stages                  NaN            NaN           NaN
# _Completion`Events                NaN            NaN           NaN
#
#                        BH_Latitude  ...  KBElevation  TotalDepth  \
# EPAssetsId                     NaN  ...          NaN         NaN
# well_status_code               NaN  ...          NaN         NaN
# CurrentOperatorParent          NaN  ...          NaN         NaN
# CurrentOperatorID              NaN  ...          NaN         NaN
# LicenseeParentCompany          NaN  ...          NaN         NaN
# LicenseeID                     NaN  ...          NaN         NaN
# Surf_Longitude                 NaN  ...          NaN         NaN
# Surf_Latitude             0.865559  ...          NaN         NaN
# BH_Longitude                   NaN  ...          NaN         NaN
# BH_Latitude               1.000000  ...          NaN         NaN
# GroundElevation                NaN  ...     0.777138         NaN
# KBElevation                    NaN  ...     1.000000    0.515222
# TotalDepth                     NaN  ...     0.515222    1.000000
# DaysDrilling                   NaN  ...          NaN         NaN
# DrillMetresPerDay              NaN  ...          NaN         NaN
# TVD                            NaN  ...     0.625651    0.873667
# NumberofWells                  NaN  ...          NaN         NaN
# ProjectedDepth                 NaN  ...          NaN    0.784001
# _Max`Prod`(BOE)                NaN  ...          NaN         NaN
# _Fracture`Stages               NaN  ...          NaN    0.530642
# _Completion`Events             NaN  ...          NaN    0.514360
#
#                        DaysDrilling  DrillMetresPerDay       TVD  \
# EPAssetsId                      NaN                NaN       NaN
# well_status_code                NaN                NaN       NaN
# CurrentOperatorParent           NaN                NaN       NaN
# CurrentOperatorID               NaN                NaN       NaN
# LicenseeParentCompany           NaN                NaN       NaN
# LicenseeID                      NaN                NaN       NaN
# Surf_Longitude                  NaN                NaN       NaN
# Surf_Latitude                   NaN                NaN       NaN
# BH_Longitude                    NaN                NaN       NaN
# BH_Latitude                     NaN                NaN       NaN
# GroundElevation                 NaN                NaN  0.601004
# KBElevation                     NaN                NaN  0.625651
# TotalDepth                      NaN                NaN  0.873667
# DaysDrilling                    1.0                NaN       NaN
# DrillMetresPerDay               NaN                1.0       NaN
# TVD                             NaN                NaN  1.000000
# NumberofWells                   NaN                NaN       NaN
# ProjectedDepth                  NaN                NaN  0.746229
# _Max`Prod`(BOE)                 NaN                NaN       NaN
# _Fracture`Stages                NaN                NaN       NaN
# _Completion`Events              NaN                NaN       NaN
#
#                        NumberofWells  ProjectedDepth  _Max`Prod`(BOE)  \
# EPAssetsId                       NaN             NaN              NaN
# well_status_code                 NaN             NaN              NaN
# CurrentOperatorParent            NaN             NaN              NaN
# CurrentOperatorID                NaN             NaN              NaN
# LicenseeParentCompany            NaN             NaN              NaN
# LicenseeID                       NaN             NaN              NaN
# Surf_Longitude                   NaN             NaN              NaN
# Surf_Latitude                    NaN             NaN              NaN
# BH_Longitude                     NaN             NaN              NaN
# BH_Latitude                      NaN             NaN              NaN
# GroundElevation                  NaN             NaN              NaN
# KBElevation                      NaN             NaN              NaN
# TotalDepth                       NaN        0.784001              NaN
# DaysDrilling                     NaN             NaN              NaN
# DrillMetresPerDay                NaN             NaN              NaN
# TVD                              NaN        0.746229              NaN
# NumberofWells                    NaN             NaN              NaN
# ProjectedDepth                   NaN        1.000000              NaN
# _Max`Prod`(BOE)                  NaN             NaN              1.0
# _Fracture`Stages                 NaN        0.647881              NaN
# _Completion`Events               NaN        0.548196              NaN
#
#                        _Fracture`Stages  _Completion`Events
# EPAssetsId                          NaN                 NaN
# well_status_code                    NaN                 NaN
# CurrentOperatorParent               NaN                 NaN
# CurrentOperatorID                   NaN                 NaN
# LicenseeParentCompany               NaN                 NaN
# LicenseeID                          NaN                 NaN
# Surf_Longitude                      NaN                 NaN
# Surf_Latitude                       NaN                 NaN
# BH_Longitude                        NaN                 NaN
# BH_Latitude                         NaN                 NaN
# GroundElevation                     NaN                 NaN
# KBElevation                         NaN                 NaN
# TotalDepth                     0.530642            0.514360
# DaysDrilling                        NaN                 NaN
# DrillMetresPerDay                   NaN                 NaN
# TVD                                 NaN                 NaN
# NumberofWells                       NaN                 NaN
# ProjectedDepth                 0.647881            0.548196
# _Max`Prod`(BOE)                     NaN                 NaN
# _Fracture`Stages               1.000000            0.593819
# _Completion`Events             0.593819            1.000000
#
# [21 rows x 21 columns]

# %%
corr[corr<-0.5]
# Out:
#                        EPAssetsId  well_status_code  CurrentOperatorParent  \
# EPAssetsId                    NaN               NaN                    NaN
# well_status_code              NaN               NaN                    NaN
# CurrentOperatorParent         NaN               NaN                    NaN
# CurrentOperatorID             NaN               NaN                    NaN
# LicenseeParentCompany         NaN               NaN                    NaN
# LicenseeID                    NaN               NaN                    NaN
# Surf_Longitude                NaN               NaN                    NaN
# Surf_Latitude                 NaN               NaN                    NaN
# BH_Longitude                  NaN               NaN                    NaN
# BH_Latitude                   NaN               NaN                    NaN
# GroundElevation               NaN               NaN                    NaN
# KBElevation                   NaN               NaN                    NaN
# TotalDepth                    NaN               NaN                    NaN
# DaysDrilling                  NaN               NaN                    NaN
# DrillMetresPerDay             NaN               NaN                    NaN
# TVD                           NaN               NaN                    NaN
# NumberofWells                 NaN               NaN                    NaN
# ProjectedDepth                NaN               NaN                    NaN
# _Max`Prod`(BOE)               NaN               NaN                    NaN
# _Fracture`Stages              NaN               NaN                    NaN
# _Completion`Events            NaN               NaN                    NaN
#
#                        CurrentOperatorID  LicenseeParentCompany  LicenseeID  \
# EPAssetsId                           NaN                    NaN         NaN
# well_status_code                     NaN                    NaN         NaN
# CurrentOperatorParent                NaN                    NaN         NaN
# CurrentOperatorID                    NaN                    NaN         NaN
# LicenseeParentCompany                NaN                    NaN         NaN
# LicenseeID                           NaN                    NaN         NaN
# Surf_Longitude                       NaN                    NaN         NaN
# Surf_Latitude                        NaN                    NaN         NaN
# BH_Longitude                         NaN                    NaN         NaN
# BH_Latitude                          NaN                    NaN         NaN
# GroundElevation                      NaN                    NaN         NaN
# KBElevation                          NaN                    NaN         NaN
# TotalDepth                           NaN                    NaN         NaN
# DaysDrilling                         NaN                    NaN         NaN
# DrillMetresPerDay                    NaN                    NaN         NaN
# TVD                                  NaN                    NaN         NaN
# NumberofWells                        NaN                    NaN         NaN
# ProjectedDepth                       NaN                    NaN         NaN
# _Max`Prod`(BOE)                      NaN                    NaN         NaN
# _Fracture`Stages                     NaN                    NaN         NaN
# _Completion`Events                   NaN                    NaN         NaN
#
#                        Surf_Longitude  Surf_Latitude  BH_Longitude  \
# EPAssetsId                        NaN            NaN           NaN
# well_status_code                  NaN            NaN           NaN
# CurrentOperatorParent             NaN            NaN           NaN
# CurrentOperatorID                 NaN            NaN           NaN
# LicenseeParentCompany             NaN            NaN           NaN
# LicenseeID                        NaN            NaN           NaN
# Surf_Longitude                    NaN      -0.706404           NaN
# Surf_Latitude               -0.706404            NaN     -0.520553
# BH_Longitude                      NaN      -0.520553           NaN
# BH_Latitude                 -0.574681            NaN     -0.751274
# GroundElevation                   NaN            NaN           NaN
# KBElevation                       NaN            NaN           NaN
# TotalDepth                        NaN            NaN           NaN
# DaysDrilling                      NaN            NaN           NaN
# DrillMetresPerDay                 NaN            NaN           NaN
# TVD                               NaN            NaN           NaN
# NumberofWells                     NaN            NaN           NaN
# ProjectedDepth                    NaN            NaN           NaN
# _Max`Prod`(BOE)                   NaN            NaN           NaN
# _Fracture`Stages                  NaN            NaN     -0.508717
# _Completion`Events                NaN            NaN           NaN
#
#                        BH_Latitude  ...  KBElevation  TotalDepth  \
# EPAssetsId                     NaN  ...          NaN         NaN
# well_status_code               NaN  ...          NaN         NaN
# CurrentOperatorParent          NaN  ...          NaN         NaN
# CurrentOperatorID              NaN  ...          NaN         NaN
# LicenseeParentCompany          NaN  ...          NaN         NaN
# LicenseeID                     NaN  ...          NaN         NaN
# Surf_Longitude           -0.574681  ...          NaN         NaN
# Surf_Latitude                  NaN  ...          NaN         NaN
# BH_Longitude             -0.751274  ...          NaN         NaN
# BH_Latitude                    NaN  ...          NaN         NaN
# GroundElevation                NaN  ...          NaN         NaN
# KBElevation                    NaN  ...          NaN         NaN
# TotalDepth                     NaN  ...          NaN         NaN
# DaysDrilling                   NaN  ...          NaN         NaN
# DrillMetresPerDay              NaN  ...          NaN         NaN
# TVD                            NaN  ...          NaN         NaN
# NumberofWells                  NaN  ...          NaN         NaN
# ProjectedDepth                 NaN  ...          NaN         NaN
# _Max`Prod`(BOE)                NaN  ...          NaN         NaN
# _Fracture`Stages               NaN  ...          NaN         NaN
# _Completion`Events             NaN  ...          NaN         NaN
#
#                        DaysDrilling  DrillMetresPerDay  TVD  NumberofWells  \
# EPAssetsId                      NaN                NaN  NaN            NaN
# well_status_code                NaN                NaN  NaN            NaN
# CurrentOperatorParent           NaN                NaN  NaN            NaN
# CurrentOperatorID               NaN                NaN  NaN            NaN
# LicenseeParentCompany           NaN                NaN  NaN            NaN
# LicenseeID                      NaN                NaN  NaN            NaN
# Surf_Longitude                  NaN                NaN  NaN            NaN
# Surf_Latitude                   NaN                NaN  NaN            NaN
# BH_Longitude                    NaN                NaN  NaN            NaN
# BH_Latitude                     NaN                NaN  NaN            NaN
# GroundElevation                 NaN                NaN  NaN            NaN
# KBElevation                     NaN                NaN  NaN            NaN
# TotalDepth                      NaN                NaN  NaN            NaN
# DaysDrilling                    NaN                NaN  NaN            NaN
# DrillMetresPerDay               NaN                NaN  NaN            NaN
# TVD                             NaN                NaN  NaN            NaN
# NumberofWells                   NaN                NaN  NaN            NaN
# ProjectedDepth                  NaN                NaN  NaN            NaN
# _Max`Prod`(BOE)                 NaN                NaN  NaN            NaN
# _Fracture`Stages                NaN                NaN  NaN            NaN
# _Completion`Events              NaN                NaN  NaN            NaN
#
#                        ProjectedDepth  _Max`Prod`(BOE)  _Fracture`Stages  \
# EPAssetsId                        NaN              NaN               NaN
# well_status_code                  NaN              NaN               NaN
# CurrentOperatorParent             NaN              NaN               NaN
# CurrentOperatorID                 NaN              NaN               NaN
# LicenseeParentCompany             NaN              NaN               NaN
# LicenseeID                        NaN              NaN               NaN
# Surf_Longitude                    NaN              NaN               NaN
# Surf_Latitude                     NaN              NaN               NaN
# BH_Longitude                      NaN              NaN         -0.508717
# BH_Latitude                       NaN              NaN               NaN
# GroundElevation                   NaN              NaN               NaN
# KBElevation                       NaN              NaN               NaN
# TotalDepth                        NaN              NaN               NaN
# DaysDrilling                      NaN              NaN               NaN
# DrillMetresPerDay                 NaN              NaN               NaN
# TVD                               NaN              NaN               NaN
# NumberofWells                     NaN              NaN               NaN
# ProjectedDepth                    NaN              NaN               NaN
# _Max`Prod`(BOE)                   NaN              NaN               NaN
# _Fracture`Stages                  NaN              NaN               NaN
# _Completion`Events                NaN              NaN               NaN
#
#                        _Completion`Events
# EPAssetsId                            NaN
# well_status_code                      NaN
# CurrentOperatorParent                 NaN
# CurrentOperatorID                     NaN
# LicenseeParentCompany                 NaN
# LicenseeID                            NaN
# Surf_Longitude                        NaN
# Surf_Latitude                         NaN
# BH_Longitude                          NaN
# BH_Latitude                           NaN
# GroundElevation                       NaN
# KBElevation                           NaN
# TotalDepth                            NaN
# DaysDrilling                          NaN
# DrillMetresPerDay                     NaN
# TVD                                   NaN
# NumberofWells                         NaN
# ProjectedDepth                        NaN
# _Max`Prod`(BOE)                       NaN
# _Fracture`Stages                      NaN
# _Completion`Events                    NaN
#
# [21 rows x 21 columns]

# %% [markdown]
# # Lets Simplify the dataset

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',100)

# %%
df_train[df_train['well_status']=='Abandoned'][df_train['SurveySystem']=='DLS']['SurveySystem'].nunique()
# Out:
# /Users/Meisam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 1

# %%
df_train[df_train['OSArea']=='Cold Lake'][df_train['well_status'] =='Active'].head(50).transpose()
# Out:
# /Users/Meisam/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                                        1     \
# EPAssetsId                                          2341273
# well_status                                          Active
# well_status_code                                          1
# Province                                            Alberta
# LicenceNumber                                       0419701
# UWI                                        100011505407W400
# CurrentOperator          Canadian Natural Resources Limited
# CurrentOperatorParent                                   159
# CurrentOperatorID                                       NaN
# Licensee                 Canadian Natural Resources Limited
# LicenseeParentCompany                                   159
# LicenseeID                                              NaN
# LicenceDate                            4/9/2010 12:00:00 AM
# WellType                                      Crude Bitumen
# WellTypeStandardised                                Bitumen
# ConfidentialReleaseDate                                 NaN
# SurfAbandonDate                                         NaN
# WellName                         CNRL 1B ST. PAUL 1-15-54-7
# WellNameAmended                  Cnrl 1b St. Paul 1-15-54-7
# Formation                                              Dina
# Field                                               Derwent
# Pool                                     Lower Grand Rapids
# SurveySystem                                            DLS
# Surf_Location                               15-10-054-07-W4
# Surf_Township                                           054
# Surf_Meridian                                            W4
# Surf_Range                                               07
# Surf_Section                                             10
# Surf_LSD                                                 15
# Surf_Longitude                                     -110.948
# Surf_Latitude                                       53.6552
# Surf_TownshipRange                                054-07-W4
# Surf_QuarterUnit                             Not Applicable
# Surf_Unit                                    Not Applicable
# Surf_Block                                   Not Applicable
# Surf_NTSMapSheet                             Not Applicable
# Surf_Series                                  Not Applicable
# Surf_Area                                    Not Applicable
# Surf_Sheet                                   Not Applicable
# Surf_QuarterSection                                      NE
# BH_Location                                 01-15-054-07-W4
# BH_TownshipRange                                  054-07-W4
# BH_QuarterUnit                               Not Applicable
# BH_Unit                                      Not Applicable
# BH_Block                                     Not Applicable
# BH_NTSMapSheet                               Not Applicable
# BH_Series                                    Not Applicable
# BH_Area                                      Not Applicable
# BH_Sheet                                     Not Applicable
# BH_QuarterSection                                        SE
# BH_Longitude                                       -110.944
# BH_Latitude                                         53.6587
# BH_Township                                             054
# BH_Meridian                                              W4
# BH_Range                                                 07
# BH_Section                                               15
# BH_LSD                                                   01
# GroundElevation                                       624.4
# KBElevation                                           628.5
# TotalDepth                                              785
# LaheeClass                                      Development
# Confidential                               Non-Confidential
# SurfaceOwner                                       Freehold
# OSArea                                            Cold Lake
# OSDeposit                                Lower Grand Rapids
# DrillingContractor           Precision Drilling Corporation
# SpudDate                              7/25/2010 12:00:00 AM
# FinalDrillDate                        7/27/2010 12:00:00 AM
# RigReleaseDate                        7/27/2010 12:00:00 AM
# DaysDrilling                                              2
# DrillMetresPerDay                                     392.5
# TVD                                                  628.77
# WellProfile                                     Directional
# WellSymbPt1                                             Oil
# Country                                              Canada
# RegulatoryAgency                                        AER
# NumberofWells                                             1
# PSACAreaCode                                            AB4
# PSACAreaName                           East Central Alberta
# ProjectedDepth                                       800.27
# StatusDate                            8/31/2010 12:00:00 AM
# StatusSource                                            AER
# UnitID                                                  NaN
# UnitName                                                NaN
# UnitFlag                                                 No
# Municipality                                            NaN
# CompletionDate                                          NaN
# Agent                                           Unspecified
# _Max`Prod`(BOE)                                     95.3827
# _Fracture`Stages                                        NaN
# _Open`Hole                                   CasedCompleted
# _Completion`Events                                      NaN
#
#                                                        20    \
# EPAssetsId                                          2438366
# well_status                                          Active
# well_status_code                                          1
# Province                                            Alberta
# LicenceNumber                                       0280194
# UWI                                        100123306805W400
# CurrentOperator          Canadian Natural Resources Limited
# CurrentOperatorParent                                   159
# CurrentOperatorID                                       NaN
# Licensee                 Canadian Natural Resources Limited
# LicenseeParentCompany                                   159
# LicenseeID                                              NaN
# LicenceDate                            1/9/2003 12:00:00 AM
# WellType                                                Gas
# WellTypeStandardised                                    Gas
# ConfidentialReleaseDate                                 NaN
# SurfAbandonDate                                         NaN
# WellName                              CVE FISHER 12-33-68-5
# WellNameAmended                       Cve Fisher 12-33-68-5
# Formation                                         Mannville
# Field                                                Fisher
# Pool                                             McMurray T
# SurveySystem                                            DLS
# Surf_Location                               12-33-068-05-W4
# Surf_Township                                           068
# Surf_Meridian                                            W4
# Surf_Range                                               05
# Surf_Section                                             33
# Surf_LSD                                                 12
# Surf_Longitude                                     -110.711
# Surf_Latitude                                       54.9313
# Surf_TownshipRange                                068-05-W4
# Surf_QuarterUnit                             Not Applicable
# Surf_Unit                                    Not Applicable
# Surf_Block                                   Not Applicable
# Surf_NTSMapSheet                             Not Applicable
# Surf_Series                                  Not Applicable
# Surf_Area                                    Not Applicable
# Surf_Sheet                                   Not Applicable
# Surf_QuarterSection                                      NW
# BH_Location                                 12-33-068-05-W4
# BH_TownshipRange                                  068-05-W4
# BH_QuarterUnit                               Not Applicable
# BH_Unit                                      Not Applicable
# BH_Block                                     Not Applicable
# BH_NTSMapSheet                               Not Applicable
# BH_Series                                    Not Applicable
# BH_Area                                      Not Applicable
# BH_Sheet                                     Not Applicable
# BH_QuarterSection                                        NW
# BH_Longitude                                       -110.711
# BH_Latitude                                         54.9313
# BH_Township                                             068
# BH_Meridian                                              W4
# BH_Range                                                 05
# BH_Section                                               33
# BH_LSD                                                   12
# GroundElevation                                       681.9
# KBElevation                                           685.3
# TotalDepth                                              481
# LaheeClass                                      Development
# Confidential                               Non-Confidential
# SurfaceOwner                                          Crown
# OSArea                                            Cold Lake
# OSDeposit                                    Not Applicable
# DrillingContractor                    Mid-West Drilling Ltd
# SpudDate                              1/19/2003 12:00:00 AM
# FinalDrillDate                         2/3/2003 12:00:00 AM
# RigReleaseDate                        1/22/2003 12:00:00 AM
# DaysDrilling                                             15
# DrillMetresPerDay                                     32.07
# TVD                                                     481
# WellProfile                                        Vertical
# WellSymbPt1                                             Gas
# Country                                              Canada
# RegulatoryAgency                                        AER
# NumberofWells                                             1
# PSACAreaCode                                            AB6
# PSACAreaName                           Northeastern Alberta
# ProjectedDepth                                          482
# StatusDate                           12/19/2003 12:00:00 AM
# StatusSource                                            AER
# UnitID                                                  NaN
# UnitName                                                NaN
# UnitFlag                                                 No
# Municipality                                            NaN
# CompletionDate                                          NaN
# Agent                                           Unspecified
# _Max`Prod`(BOE)                                     37.6495
# _Fracture`Stages                                        NaN
# _Open`Hole                                   CasedCompleted
# _Completion`Events                                      NaN
#
#                                            46    \
# EPAssetsId                              2357291
# well_status                              Active
# well_status_code                              1
# Province                                Alberta
# LicenceNumber                           0130457
# UWI                            100092005603W402
# CurrentOperator          West Lake Energy Corp.
# CurrentOperatorParent                      9514
# CurrentOperatorID                           NaN
# Licensee                 West Lake Energy Corp.
# LicenseeParentCompany                      9514
# LicenseeID                                  NaN
# LicenceDate               12/4/1987 12:00:00 AM
# WellType                                    Gas
# WellTypeStandardised                        Gas
# ConfidentialReleaseDate  12/19/1988 12:00:00 AM
# SurfAbandonDate                             NaN
# WellName                    WLEC LIND 9-20-56-3
# WellNameAmended             Wlec Lind 9-20-56-3
# Formation                                   Rex
# Field                                 Lindbergh
# Pool                        Commingled Pool 002
# SurveySystem                                DLS
# Surf_Location                   09-20-056-03-W4
# Surf_Township                               056
# Surf_Meridian                                W4
# Surf_Range                                   03
# Surf_Section                                 20
# Surf_LSD                                     09
# Surf_Longitude                         -110.406
# Surf_Latitude                           53.8561
# Surf_TownshipRange                    056-03-W4
# Surf_QuarterUnit                 Not Applicable
# Surf_Unit                        Not Applicable
# Surf_Block                       Not Applicable
# Surf_NTSMapSheet                 Not Applicable
# Surf_Series                      Not Applicable
# Surf_Area                        Not Applicable
# Surf_Sheet                       Not Applicable
# Surf_QuarterSection                          NE
# BH_Location                     09-20-056-03-W4
# BH_TownshipRange                      056-03-W4
# BH_QuarterUnit                   Not Applicable
# BH_Unit                          Not Applicable
# BH_Block                         Not Applicable
# BH_NTSMapSheet                   Not Applicable
# BH_Series                        Not Applicable
# BH_Area                          Not Applicable
# BH_Sheet                         Not Applicable
# BH_QuarterSection                            NE
# BH_Longitude                           -110.406
# BH_Latitude                             53.8561
# BH_Township                                 056
# BH_Meridian                                  W4
# BH_Range                                     03
# BH_Section                                   20
# BH_LSD                                       09
# GroundElevation                           612.5
# KBElevation                               615.5
# TotalDepth                                  493
# LaheeClass                          Development
# Confidential                   Non-Confidential
# SurfaceOwner                           Freehold
# OSArea                                Cold Lake
# OSDeposit                        Not Applicable
# DrillingContractor               Sedco Drilling
# SpudDate                 12/18/1987 12:00:00 AM
# FinalDrillDate           12/19/1987 12:00:00 AM
# RigReleaseDate           12/20/1987 12:00:00 AM
# DaysDrilling                                  1
# DrillMetresPerDay                           493
# TVD                                         493
# WellProfile                            Vertical
# WellSymbPt1                                 Gas
# Country                                  Canada
# RegulatoryAgency                            AER
# NumberofWells                                 1
# PSACAreaCode                                AB4
# PSACAreaName               East Central Alberta
# ProjectedDepth                              NaN
# StatusDate               10/22/2007 12:00:00 AM
# StatusSource                                AER
# UnitID                                      NaN
# UnitName                                    NaN
# UnitFlag                                     No
# Municipality                                NaN
# CompletionDate                              NaN
# Agent                               Unspecified
# _Max`Prod`(BOE)                         1.19678
# _Fracture`Stages                            NaN
# _Open`Hole                       CasedCompleted
# _Completion`Events                          NaN
#
#                                                        171   \
# EPAssetsId                                          2582033
# well_status                                          Active
# well_status_code                                          1
# Province                                            Alberta
# LicenceNumber                                       0471092
# UWI                                        102010105702W400
# CurrentOperator          Canadian Natural Resources Limited
# CurrentOperatorParent                                   159
# CurrentOperatorID                                       NaN
# Licensee                 Canadian Natural Resources Limited
# LicenseeParentCompany                                   159
# LicenseeID                                              NaN
# LicenceDate                           11/4/2014 12:00:00 AM
# WellType                                      Crude Bitumen
# WellTypeStandardised                                Bitumen
# ConfidentialReleaseDate                                 NaN
# SurfAbandonDate                                         NaN
# WellName                           CNRL 1B FROG LK 1-1-57-2
# WellNameAmended                    Cnrl 1b Frog Lk 1-1-57-2
# Formation                                          McMurray
# Field                                             Lindbergh
# Pool                                     Upper Grand Rapids
# SurveySystem                                            DLS
# Surf_Location                               04-06-057-01-W4
# Surf_Township                                           057
# Surf_Meridian                                            W4
# Surf_Range                                               01
# Surf_Section                                             06
# Surf_LSD                                                 04
# Surf_Longitude                                      -110.15
# Surf_Latitude                                       53.8904
# Surf_TownshipRange                                057-01-W4
# Surf_QuarterUnit                             Not Applicable
# Surf_Unit                                    Not Applicable
# Surf_Block                                   Not Applicable
# Surf_NTSMapSheet                             Not Applicable
# Surf_Series                                  Not Applicable
# Surf_Area                                    Not Applicable
# Surf_Sheet                                   Not Applicable
# Surf_QuarterSection                                      SW
# BH_Location                                 01-01-057-02-W4
# BH_TownshipRange                                  057-02-W4
# BH_QuarterUnit                               Not Applicable
# BH_Unit                                      Not Applicable
# BH_Block                                     Not Applicable
# BH_NTSMapSheet                               Not Applicable
# BH_Series                                    Not Applicable
# BH_Area                                      Not Applicable
# BH_Sheet                                     Not Applicable
# BH_QuarterSection                                        SE
# BH_Longitude                                       -110.159
# BH_Latitude                                         53.8897
# BH_Township                                             057
# BH_Meridian                                              W4
# BH_Range                                                 02
# BH_Section                                               01
# BH_LSD                                                   01
# GroundElevation                                       658.2
# KBElevation                                           662.4
# TotalDepth                                              799
# LaheeClass                                      Development
# Confidential                               Non-Confidential
# SurfaceOwner                                       Freehold
# OSArea                                            Cold Lake
# OSDeposit                                Upper Grand Rapids
# DrillingContractor            Bluerock Energy Services Ltd.
# SpudDate                              9/12/2016 12:00:00 AM
# FinalDrillDate                        9/15/2016 12:00:00 AM
# RigReleaseDate                        9/16/2016 12:00:00 AM
# DaysDrilling                                              3
# DrillMetresPerDay                                    266.33
# TVD                                                  526.98
# WellProfile                                     Directional
# WellSymbPt1                                             Oil
# Country                                              Canada
# RegulatoryAgency                                        AER
# NumberofWells                                             1
# PSACAreaCode                                            AB4
# PSACAreaName                           East Central Alberta
# ProjectedDepth                                        871.6
# StatusDate                           10/14/2016 12:00:00 AM
# StatusSource                                            AER
# UnitID                                                  NaN
# UnitName                                                NaN
# UnitFlag                                                 No
# Municipality                                            NaN
# CompletionDate                                          NaN
# Agent                                           Unspecified
# _Max`Prod`(BOE)                                     103.389
# _Fracture`Stages                                        NaN
# _Open`Hole                                   CasedCompleted
# _Completion`Events                                        3
#
#                                                    398   \
# EPAssetsId                                      2419158
# well_status                                      Active
# well_status_code                                      1
# Province                                        Alberta
# LicenceNumber                                   0132578
# UWI                                    100041906503W402
# CurrentOperator                     No Current Operator
# CurrentOperatorParent                              1108
# CurrentOperatorID                                   NaN
# Licensee                 Imperial Oil Resources Limited
# LicenseeParentCompany                               349
# LicenseeID                                          NaN
# LicenceDate                       2/24/1988 12:00:00 AM
# WellType                                    Observation
# WellTypeStandardised                        Observation
# ConfidentialReleaseDate                             NaN
# SurfAbandonDate                   3/13/1988 12:00:00 AM
# WellName                 ESSO 88 C7-13 COLDLK 4-19-65-3
# WellNameAmended          Esso 88 C7-13 Coldlk 4-19-65-3
# Formation                                    Clearwater
# Field                             Undefined - Cold Lake
# Pool                             Grand Rapids Undefined
# SurveySystem                                        DLS
# Surf_Location                           04-19-065-03-W4
# Surf_Township                                       065
# Surf_Meridian                                        W4
# Surf_Range                                           03
# Surf_Section                                         19
# Surf_LSD                                             04
# Surf_Longitude                                 -110.455
# Surf_Latitude                                   54.6337
# Surf_TownshipRange                            065-03-W4
# Surf_QuarterUnit                         Not Applicable
# Surf_Unit                                Not Applicable
# Surf_Block                               Not Applicable
# Surf_NTSMapSheet                         Not Applicable
# Surf_Series                              Not Applicable
# Surf_Area                                Not Applicable
# Surf_Sheet                               Not Applicable
# Surf_QuarterSection                                  SW
# BH_Location                             04-19-065-03-W4
# BH_TownshipRange                              065-03-W4
# BH_QuarterUnit                           Not Applicable
# BH_Unit                                  Not Applicable
# BH_Block                                 Not Applicable
# BH_NTSMapSheet                           Not Applicable
# BH_Series                                Not Applicable
# BH_Area                                  Not Applicable
# BH_Sheet                                 Not Applicable
# BH_QuarterSection                                    SW
# BH_Longitude                                   -110.456
# BH_Latitude                                     54.6333
# BH_Township                                         065
# BH_Meridian                                          W4
# BH_Range                                             03
# BH_Section                                           19
# BH_LSD                                               04
# GroundElevation                                   603.5
# KBElevation                                       606.5
# TotalDepth                                          470
# LaheeClass                                  Development
# Confidential                           Non-Confidential
# SurfaceOwner                                      Crown
# OSArea                                        Cold Lake
# OSDeposit                                Not Applicable
# DrillingContractor                       Sedco Drilling
# SpudDate                           2/9/1989 12:00:00 AM
# FinalDrillDate                    2/11/1989 12:00:00 AM
# RigReleaseDate                     3/3/1989 12:00:00 AM
# DaysDrilling                                          2
# DrillMetresPerDay                                   235
# TVD                                              464.58
# WellProfile                                 Directional
# WellSymbPt1                                       Other
# Country                                          Canada
# RegulatoryAgency                                    AER
# NumberofWells                                         1
# PSACAreaCode                                        AB6
# PSACAreaName                       Northeastern Alberta
# ProjectedDepth                                      520
# StatusDate                         3/4/1989 12:00:00 AM
# StatusSource                                        AER
# UnitID                                              NaN
# UnitName                                            NaN
# UnitFlag                                             No
# Municipality                                        NaN
# CompletionDate                                      NaN
# Agent                                       Unspecified
# _Max`Prod`(BOE)                                     NaN
# _Fracture`Stages                                    NaN
# _Open`Hole                               CasedCompleted
# _Completion`Events                                  NaN
#
#                                                    414   \
# EPAssetsId                                      2418293
# well_status                                      Active
# well_status_code                                      1
# Province                                        Alberta
# LicenceNumber                                   0184632
# UWI                                    103150606503W400
# CurrentOperator          Imperial Oil Resources Limited
# CurrentOperatorParent                               349
# CurrentOperatorID                                   NaN
# Licensee                 Imperial Oil Resources Limited
# LicenseeParentCompany                               349
# LicenseeID                                          NaN
# LicenceDate                       1/16/1996 12:00:00 AM
# WellType                         Cyclical Crude Bitumen
# WellTypeStandardised                 Bitumen - Cyclical
# ConfidentialReleaseDate                             NaN
# SurfAbandonDate                                     NaN
# WellName                  IMP 96 LL-02 COLDLK 15-6-65-3
# WellNameAmended           Imp 96 Ll-02 Coldlk 15-6-65-3
# Formation                                    Clearwater
# Field                             Undefined - Cold Lake
# Pool                                         Clearwater
# SurveySystem                                        DLS
# Surf_Location                           10-06-065-03-W4
# Surf_Township                                       065
# Surf_Meridian                                        W4
# Surf_Range                                           03
# Surf_Section                                         06
# Surf_LSD                                             10
# Surf_Longitude                                 -110.442
# Surf_Latitude                                   54.5974
# Surf_TownshipRange                            065-03-W4
# Surf_QuarterUnit                         Not Applicable
# Surf_Unit                                Not Applicable
# Surf_Block                               Not Applicable
# Surf_NTSMapSheet                         Not Applicable
# Surf_Series                              Not Applicable
# Surf_Area                                Not Applicable
# Surf_Sheet                               Not Applicable
# Surf_QuarterSection                                  NE
# BH_Location                             15-06-065-03-W4
# BH_TownshipRange                              065-03-W4
# BH_QuarterUnit                           Not Applicable
# BH_Unit                                  Not Applicable
# BH_Block                                 Not Applicable
# BH_NTSMapSheet                           Not Applicable
# BH_Series                                Not Applicable
# BH_Area                                  Not Applicable
# BH_Sheet                                 Not Applicable
# BH_QuarterSection                                    NE
# BH_Longitude                                   -110.442
# BH_Latitude                                     54.5996
# BH_Township                                         065
# BH_Meridian                                          W4
# BH_Range                                             03
# BH_Section                                           06
# BH_LSD                                               15
# GroundElevation                                   629.2
# KBElevation                                       633.3
# TotalDepth                                          574
# LaheeClass                                  Development
# Confidential                           Non-Confidential
# SurfaceOwner                                      Crown
# OSArea                                        Cold Lake
# OSDeposit                                    Clearwater
# DrillingContractor                       Sedco Drilling
# SpudDate                          2/19/1996 12:00:00 AM
# FinalDrillDate                    2/19/1996 12:00:00 AM
# RigReleaseDate                    2/19/1996 12:00:00 AM
# DaysDrilling                                          1
# DrillMetresPerDay                                   574
# TVD                                              496.35
# WellProfile                                 Directional
# WellSymbPt1                                         Oil
# Country                                          Canada
# RegulatoryAgency                                    AER
# NumberofWells                                         1
# PSACAreaCode                                        AB6
# PSACAreaName                       Northeastern Alberta
# ProjectedDepth                                      584
# StatusDate                        8/19/1996 12:00:00 AM
# StatusSource                                        AER
# UnitID                                              NaN
# UnitName                                            NaN
# UnitFlag                                             No
# Municipality                                        NaN
# CompletionDate                                      NaN
# Agent                                       Unspecified
# _Max`Prod`(BOE)                                     NaN
# _Fracture`Stages                                    NaN
# _Open`Hole                               CasedCompleted
# _Completion`Events                                  NaN
#
#                                                     445   \
# EPAssetsId                                       2421081
# well_status                                       Active
# well_status_code                                       1
# Province                                         Alberta
# LicenceNumber                                    0112735
# UWI                                     108112206504W400
# CurrentOperator           Imperial Oil Resources Limited
# CurrentOperatorParent                                349
# CurrentOperatorID                                    NaN
# Licensee                  Imperial Oil Resources Limited
# LicenseeParentCompany                                349
# LicenseeID                                           NaN
# LicenceDate                        1/23/1985 12:00:00 AM
# WellType                          Cyclical Crude Bitumen
# WellTypeStandardised                  Bitumen - Cyclical
# ConfidentialReleaseDate            2/14/1986 12:00:00 AM
# SurfAbandonDate                                      NaN
# WellName                 ESSO 84 J5-16 COLDLK 11-22-65-4
# WellNameAmended          Esso 84 J5-16 Coldlk 11-22-65-4
# Formation                                       McMurray
# Field                                             Leming
# Pool                                          Clearwater
# SurveySystem                                         DLS
# Surf_Location                            10-22-065-04-W4
# Surf_Township                                        065
# Surf_Meridian                                         W4
# Surf_Range                                            04
# Surf_Section                                          22
# Surf_LSD                                              10
# Surf_Longitude                                  -110.519
# Surf_Latitude                                    54.6399
# Surf_TownshipRange                             065-04-W4
# Surf_QuarterUnit                          Not Applicable
# Surf_Unit                                 Not Applicable
# Surf_Block                                Not Applicable
# Surf_NTSMapSheet                          Not Applicable
# Surf_Series                               Not Applicable
# Surf_Area                                 Not Applicable
# Surf_Sheet                                Not Applicable
# Surf_QuarterSection                                   NE
# BH_Location                              11-22-065-04-W4
# BH_TownshipRange                               065-04-W4
# BH_QuarterUnit                            Not Applicable
# BH_Unit                                   Not Applicable
# BH_Block                                  Not Applicable
# BH_NTSMapSheet                            Not Applicable
# BH_Series                                 Not Applicable
# BH_Area                                   Not Applicable
# BH_Sheet                                  Not Applicable
# BH_QuarterSection                                     NW
# BH_Longitude                                    -110.524
# BH_Latitude                                       54.639
# BH_Township                                          065
# BH_Meridian                                           W4
# BH_Range                                              04
# BH_Section                                            22
# BH_LSD                                                11
# GroundElevation                                    607.7
# KBElevation                                          612
# TotalDepth                                           626
# LaheeClass                                   Development
# Confidential                            Non-Confidential
# SurfaceOwner                                       Crown
# OSArea                                         Cold Lake
# OSDeposit                                     Clearwater
# DrillingContractor                   Ensign Drilling Inc
# SpudDate                           2/13/1985 12:00:00 AM
# FinalDrillDate                     2/14/1985 12:00:00 AM
# RigReleaseDate                     2/15/1985 12:00:00 AM
# DaysDrilling                                           1
# DrillMetresPerDay                                    626
# TVD                                               493.68
# WellProfile                                  Directional
# WellSymbPt1                                          Oil
# Country                                           Canada
# RegulatoryAgency                                     AER
# NumberofWells                                          1
# PSACAreaCode                                         AB6
# PSACAreaName                        Northeastern Alberta
# ProjectedDepth                                       NaN
# StatusDate                         12/1/2015 12:00:00 AM
# StatusSource                                         AER
# UnitID                                               NaN
# UnitName                                             NaN
# UnitFlag                                              No
# Municipality                                         NaN
# CompletionDate                                       NaN
# Agent                                        Unspecified
# _Max`Prod`(BOE)                                  168.975
# _Fracture`Stages                                     NaN
# _Open`Hole                                CasedCompleted
# _Completion`Events                                   NaN
#
#                                                        469   \
# EPAssetsId                                          2437657
# well_status                                          Active
# well_status_code                                          1
# Province                                            Alberta
# LicenceNumber                                       0424670
# UWI                                        100050306804W400
# CurrentOperator                         No Current Operator
# CurrentOperatorParent                                  1108
# CurrentOperatorID                                       NaN
# Licensee                 Canadian Natural Resources Limited
# LicenseeParentCompany                                   159
# LicenseeID                                              NaN
# LicenceDate                          10/14/2010 12:00:00 AM
# WellType                                              Drain
# WellTypeStandardised                                  Drain
# ConfidentialReleaseDate                                 NaN
# SurfAbandonDate                                         NaN
# WellName                       CNRL 16A24 PRIMROSE 5-3-68-4
# WellNameAmended                Cnrl 16a24 Primrose 5-3-68-4
# Formation                                        Clearwater
# Field                                                Fisher
# Pool                                            Unspecified
# SurveySystem                                            DLS
# Surf_Location                               14-34-067-04-W4
# Surf_Township                                           067
# Surf_Meridian                                            W4
# Surf_Range                                               04
# Surf_Section                                             34
# Surf_LSD                                                 14
# Surf_Longitude                                     -110.531
# Surf_Latitude                                       54.8495
# Surf_TownshipRange                                067-04-W4
# Surf_QuarterUnit                             Not Applicable
# Surf_Unit                                    Not Applicable
# Surf_Block                                   Not Applicable
# Surf_NTSMapSheet                             Not Applicable
# Surf_Series                                  Not Applicable
# Surf_Area                                    Not Applicable
# Surf_Sheet                                   Not Applicable
# Surf_QuarterSection                                      NW
# BH_Location                                 05-03-068-04-W4
# BH_TownshipRange                                  068-04-W4
# BH_QuarterUnit                               Not Applicable
# BH_Unit                                      Not Applicable
# BH_Block                                     Not Applicable
# BH_NTSMapSheet                               Not Applicable
# BH_Series                                    Not Applicable
# BH_Area                                      Not Applicable
# BH_Sheet                                     Not Applicable
# BH_QuarterSection                                        SW
# BH_Longitude                                       -110.538
# BH_Latitude                                          54.854
# BH_Township                                             068
# BH_Meridian                                              W4
# BH_Range                                                 04
# BH_Section                                               03
# BH_LSD                                                   05
# GroundElevation                                       702.3
# KBElevation                                           707.2
# TotalDepth                                             1114
# LaheeClass                                      Development
# Confidential                               Non-Confidential
# SurfaceOwner                                          Crown
# OSArea                                            Cold Lake
# OSDeposit                                    Not Applicable
# DrillingContractor                      Ensign Drilling Inc
# SpudDate                             11/19/2010 12:00:00 AM
# FinalDrillDate                         4/9/2011 12:00:00 AM
# RigReleaseDate                        4/12/2011 12:00:00 AM
# DaysDrilling                                            141
# DrillMetresPerDay                                       7.9
# TVD                                                  492.04
# WellProfile                                      Horizontal
# WellSymbPt1                                           Other
# Country                                              Canada
# RegulatoryAgency                                        AER
# NumberofWells                                             1
# PSACAreaCode                                            AB6
# PSACAreaName                           Northeastern Alberta
# ProjectedDepth                                         1937
# StatusDate                             4/9/2011 12:00:00 AM
# StatusSource                                            AER
# UnitID                                                  NaN
# UnitName                                                NaN
# UnitFlag                                                 No
# Municipality                                            NaN
# CompletionDate                                          NaN
# Agent                                           Unspecified
# _Max`Prod`(BOE)                                         NaN
# _Fracture`Stages                                        NaN
# _Open`Hole                                   CasedCompleted
# _Completion`Events                                      NaN
#
#                                                  470   \
# EPAssetsId                                    2616979
# well_status                                    Active
# well_status_code                                    1
# Province                                      Alberta
# LicenceNumber                                 0417232
# UWI                                  100140705405W402
# CurrentOperator          Husky Oil Operations Limited
# CurrentOperatorParent                             334
# CurrentOperatorID                                 NaN
# Licensee                 Husky Oil Operations Limited
# LicenseeParentCompany                             334
# LicenseeID                                        NaN
# LicenceDate                     1/13/2010 12:00:00 AM
# WellType                                Crude Bitumen
# WellTypeStandardised                          Bitumen
# ConfidentialReleaseDate                           NaN
# SurfAbandonDate                                   NaN
# WellName                  HUSKY 14D LNDBRGH 14-7-54-5
# WellNameAmended           Husky 14d Lndbrgh 14-7-54-5
# Formation                                    Cummings
# Field                                       Lindbergh
# Pool                               Upper Grand Rapids
# SurveySystem                                      DLS
# Surf_Location                         14-07-054-05-W4
# Surf_Township                                     054
# Surf_Meridian                                      W4
# Surf_Range                                         05
# Surf_Section                                       07
# Surf_LSD                                           14
# Surf_Longitude                               -110.734
# Surf_Latitude                                 53.6552
# Surf_TownshipRange                          054-05-W4
# Surf_QuarterUnit                       Not Applicable
# Surf_Unit                              Not Applicable
# Surf_Block                             Not Applicable
# Surf_NTSMapSheet                       Not Applicable
# Surf_Series                            Not Applicable
# Surf_Area                              Not Applicable
# Surf_Sheet                             Not Applicable
# Surf_QuarterSection                                NW
# BH_Location                           14-07-054-05-W4
# BH_TownshipRange                            054-05-W4
# BH_QuarterUnit                         Not Applicable
# BH_Unit                                Not Applicable
# BH_Block                               Not Applicable
# BH_NTSMapSheet                         Not Applicable
# BH_Series                              Not Applicable
# BH_Area                                Not Applicable
# BH_Sheet                               Not Applicable
# BH_QuarterSection                                  NW
# BH_Longitude                                 -110.731
# BH_Latitude                                   53.6558
# ...
# WellTypeStandardised                                Bitumen
# ConfidentialReleaseDate                                 NaN
# SurfAbandonDate                                         NaN
# WellName                        AMOCO LINDBERGH 15A-14-55-6
# WellNameAmended                 Amoco Lindbergh 15a-14-55-6
# Formation                                       Unspecified
# Field                                             Lindbergh
# Pool                                     Upper Grand Rapids
# SurveySystem                                            DLS
# Surf_Location                               15-14-055-06-W4
# Surf_Township                                           055
# Surf_Meridian                                            W4
# Surf_Range                                               06
# Surf_Section                                             14
# Surf_LSD                                                 15
# Surf_Longitude                                     -110.779
# Surf_Latitude                                       53.7557
# Surf_TownshipRange                                055-06-W4
# Surf_QuarterUnit                             Not Applicable
# Surf_Unit                                    Not Applicable
# Surf_Block                                   Not Applicable
# Surf_NTSMapSheet                             Not Applicable
# Surf_Series                                  Not Applicable
# Surf_Area                                    Not Applicable
# Surf_Sheet                                   Not Applicable
# Surf_QuarterSection                                      NE
# BH_Location                                 15-14-055-06-W4
# BH_TownshipRange                                  055-06-W4
# BH_QuarterUnit                               Not Applicable
# BH_Unit                                      Not Applicable
# BH_Block                                     Not Applicable
# BH_NTSMapSheet                               Not Applicable
# BH_Series                                    Not Applicable
# BH_Area                                      Not Applicable
# BH_Sheet                                     Not Applicable
# BH_QuarterSection                                        NE
# BH_Longitude                                       -110.779
# BH_Latitude                                         53.7557
# BH_Township                                             055
# BH_Meridian                                              W4
# BH_Range                                                 06
# BH_Section                                               14
# BH_LSD                                                   15
# GroundElevation                                         640
# KBElevation                                           643.5
# TotalDepth                                              610
# LaheeClass                                      Development
# Confidential                               Non-Confidential
# SurfaceOwner                                    Unspecified
# OSArea                                            Cold Lake
# OSDeposit                                Upper Grand Rapids
# DrillingContractor                              Unspecified
# SpudDate                              3/13/1982 12:00:00 AM
# FinalDrillDate                        3/15/1982 12:00:00 AM
# RigReleaseDate                                          NaN
# DaysDrilling                                              2
# DrillMetresPerDay                                       305
# TVD                                                     610
# WellProfile                                        Vertical
# WellSymbPt1                                             Oil
# Country                                              Canada
# RegulatoryAgency                                        AER
# NumberofWells                                             1
# PSACAreaCode                                            AB4
# PSACAreaName                           East Central Alberta
# ProjectedDepth                                          NaN
# StatusDate                           11/21/1995 12:00:00 AM
# StatusSource                                            AER
# UnitID                                                  NaN
# UnitName                                                NaN
# UnitFlag                                                 No
# Municipality                                            NaN
# CompletionDate                                          NaN
# Agent                                           Unspecified
# _Max`Prod`(BOE)                                     13.6942
# _Fracture`Stages                                        NaN
# _Open`Hole                                   CasedCompleted
# _Completion`Events                                      NaN
#
#                                                    3285  \
# EPAssetsId                                      2420052
# well_status                                      Active
# well_status_code                                      1
# Province                                        Alberta
# LicenceNumber                                   0291809
# UWI                                    110031206504W400
# CurrentOperator          Imperial Oil Resources Limited
# CurrentOperatorParent                               349
# CurrentOperatorID                                   NaN
# Licensee                 Imperial Oil Resources Limited
# LicenseeParentCompany                               349
# LicenseeID                                          NaN
# LicenceDate                       8/22/2003 12:00:00 AM
# WellType                         Cyclical Crude Bitumen
# WellTypeStandardised                 Bitumen - Cyclical
# ConfidentialReleaseDate                             NaN
# SurfAbandonDate                                     NaN
# WellName                 IMP 03 E01-18 COLDLK 3-12-65-4
# WellNameAmended          Imp 03 E01-18 Coldlk 3-12-65-4
# Formation                                    Clearwater
# Field                                            Leming
# Pool                                         Clearwater
# SurveySystem                                        DLS
# Surf_Location                           03-12-065-04-W4
# Surf_Township                                       065
# Surf_Meridian                                        W4
# Surf_Range                                           04
# Surf_Section                                         12
# Surf_LSD                                             03
# Surf_Longitude                                 -110.473
# Surf_Latitude                                   54.6057
# Surf_TownshipRange                            065-04-W4
# Surf_QuarterUnit                         Not Applicable
# Surf_Unit                                Not Applicable
# Surf_Block                               Not Applicable
# Surf_NTSMapSheet                         Not Applicable
# Surf_Series                              Not Applicable
# Surf_Area                                Not Applicable
# Surf_Sheet                               Not Applicable
# Surf_QuarterSection                                  SW
# BH_Location                             03-12-065-04-W4
# BH_TownshipRange                              065-04-W4
# BH_QuarterUnit                           Not Applicable
# BH_Unit                                  Not Applicable
# BH_Block                                 Not Applicable
# BH_NTSMapSheet                           Not Applicable
# BH_Series                                Not Applicable
# BH_Area                                  Not Applicable
# BH_Sheet                                 Not Applicable
# BH_QuarterSection                                    SW
# BH_Longitude                                   -110.473
# BH_Latitude                                     54.6043
# BH_Township                                         065
# BH_Meridian                                          W4
# BH_Range                                             04
# BH_Section                                           12
# BH_LSD                                               03
# GroundElevation                                   600.1
# KBElevation                                       606.9
# TotalDepth                                          526
# LaheeClass                                  Development
# Confidential                           Non-Confidential
# SurfaceOwner                                      Crown
# OSArea                                        Cold Lake
# OSDeposit                                    Clearwater
# DrillingContractor                   Akita Drilling Ltd
# SpudDate                          2/15/2004 12:00:00 AM
# FinalDrillDate                    2/15/2004 12:00:00 AM
# RigReleaseDate                    2/16/2004 12:00:00 AM
# DaysDrilling                                          1
# DrillMetresPerDay                                   526
# TVD                                              466.42
# WellProfile                                 Directional
# WellSymbPt1                                         Oil
# Country                                          Canada
# RegulatoryAgency                                    AER
# NumberofWells                                         1
# PSACAreaCode                                        AB6
# PSACAreaName                       Northeastern Alberta
# ProjectedDepth                                      526
# StatusDate                         9/1/2004 12:00:00 AM
# StatusSource                                        AER
# UnitID                                              NaN
# UnitName                                            NaN
# UnitFlag                                             No
# Municipality                                        NaN
# CompletionDate                                      NaN
# Agent                                       Unspecified
# _Max`Prod`(BOE)                                 158.746
# _Fracture`Stages                                    NaN
# _Open`Hole                               CasedCompleted
# _Completion`Events                                  NaN
#
#                                                      3318
# EPAssetsId                                        2411642
# well_status                                        Active
# well_status_code                                        1
# Province                                          Alberta
# LicenceNumber                                     0356857
# UWI                                      109143506403W400
# CurrentOperator            Imperial Oil Resources Limited
# CurrentOperatorParent                                 349
# CurrentOperatorID                                     NaN
# Licensee                   Imperial Oil Resources Limited
# LicenseeParentCompany                                 349
# LicenseeID                                            NaN
# LicenceDate                          5/8/2006 12:00:00 AM
# WellType                           Cyclical Crude Bitumen
# WellTypeStandardised                   Bitumen - Cyclical
# ConfidentialReleaseDate                               NaN
# SurfAbandonDate                                       NaN
# WellName                 IMP 06 U09-19 COLD LK 14-35-64-3
# WellNameAmended          Imp 06 U09-19 Cold Lk 14-35-64-3
# Formation                                      Clearwater
# Field                                          Ethel Lake
# Pool                                           Clearwater
# SurveySystem                                          DLS
# Surf_Location                             03-02-065-03-W4
# Surf_Township                                         065
# Surf_Meridian                                          W4
# Surf_Range                                             03
# Surf_Section                                           02
# Surf_LSD                                               03
# Surf_Longitude                                   -110.349
# Surf_Latitude                                     54.5882
# Surf_TownshipRange                              065-03-W4
# Surf_QuarterUnit                           Not Applicable
# Surf_Unit                                  Not Applicable
# Surf_Block                                 Not Applicable
# Surf_NTSMapSheet                           Not Applicable
# Surf_Series                                Not Applicable
# Surf_Area                                  Not Applicable
# Surf_Sheet                                 Not Applicable
# Surf_QuarterSection                                    SW
# BH_Location                               14-35-064-03-W4
# BH_TownshipRange                                064-03-W4
# BH_QuarterUnit                             Not Applicable
# BH_Unit                                    Not Applicable
# BH_Block                                   Not Applicable
# BH_NTSMapSheet                             Not Applicable
# BH_Series                                  Not Applicable
# BH_Area                                    Not Applicable
# BH_Sheet                                   Not Applicable
# BH_QuarterSection                                      NW
# BH_Longitude                                     -110.346
# BH_Latitude                                       54.5869
# BH_Township                                           064
# BH_Meridian                                            W4
# BH_Range                                               03
# BH_Section                                             35
# BH_LSD                                                 14
# GroundElevation                                       638
# KBElevation                                         645.1
# TotalDepth                                            600
# LaheeClass                                    Development
# Confidential                             Non-Confidential
# SurfaceOwner                                        Crown
# OSArea                                          Cold Lake
# OSDeposit                                      Clearwater
# DrillingContractor                    Ensign Drilling Inc
# SpudDate                             8/1/2006 12:00:00 AM
# FinalDrillDate                       8/2/2006 12:00:00 AM
# RigReleaseDate                       8/2/2006 12:00:00 AM
# DaysDrilling                                            1
# DrillMetresPerDay                                     600
# TVD                                                506.21
# WellProfile                                   Directional
# WellSymbPt1                                           Oil
# Country                                            Canada
# RegulatoryAgency                                      AER
# NumberofWells                                           1
# PSACAreaCode                                          AB6
# PSACAreaName                         Northeastern Alberta
# ProjectedDepth                                      847.3
# StatusDate                           5/1/2007 12:00:00 AM
# StatusSource                                          AER
# UnitID                                                NaN
# UnitName                                              NaN
# UnitFlag                                               No
# Municipality                                          NaN
# CompletionDate                                        NaN
# Agent                                         Unspecified
# _Max`Prod`(BOE)                                   153.423
# _Fracture`Stages                                      NaN
# _Open`Hole                                 CasedCompleted
# _Completion`Events                                    NaN

# %%
df_train.nunique()
# Out:
# EPAssetsId                 588673
# well_status                     3
# well_status_code                3
# Province                        4
# LicenceNumber              485571
# UWI                        582171
# CurrentOperator              1468
# CurrentOperatorParent        1114
# CurrentOperatorID             666
# Licensee                     4307
# LicenseeParentCompany        3257
# LicenseeID                    374
# LicenceDate                 19975
# WellType                      149
# WellTypeStandardised           65
# ConfidentialReleaseDate     23392
# SurfAbandonDate             22643
# WellName                   471104
# WellNameAmended            471104
# Formation                     591
# Field                        1997
# Pool                        11028
# SurveySystem                    2
# Surf_Location              361759
# Surf_Township                 128
# Surf_Meridian                  11
# Surf_Range                     37
# Surf_Section                   38
# Surf_LSD                       18
# Surf_Longitude             455476
# Surf_Latitude              452679
# Surf_TownshipRange           8303
# Surf_QuarterUnit                5
# Surf_Unit                     101
# Surf_Block                     13
# Surf_NTSMapSheet              191
# Surf_Series                     8
# Surf_Area                      16
# Surf_Sheet                     17
# Surf_QuarterSection             6
# BH_Location                395508
# BH_TownshipRange             8400
# BH_QuarterUnit                  5
# BH_Unit                       101
# BH_Block                       13
# BH_NTSMapSheet                181
# BH_Series                       8
# BH_Area                        16
# BH_Sheet                       17
# BH_QuarterSection               5
# BH_Longitude               452880
# BH_Latitude                450233
# BH_Township                   157
# BH_Meridian                    10
# BH_Range                       36
# BH_Section                     38
# BH_LSD                         18
# GroundElevation             16100
# KBElevation                 15586
# TotalDepth                  25690
# LaheeClass                     17
# Confidential                    5
# SurfaceOwner                 1303
# OSArea                          5
# OSDeposit                      13
# DrillingContractor           3617
# SpudDate                    27116
# FinalDrillDate              27257
# RigReleaseDate              23371
# DaysDrilling                 1695
# DrillMetresPerDay           70047
# TVD                         96613
# WellProfile                     5
# WellSymbPt1                     5
# Country                         1
# RegulatoryAgency                4
# NumberofWells                   1
# PSACAreaCode                   15
# PSACAreaName                   15
# ProjectedDepth              20813
# StatusDate                  26245
# StatusSource                    6
# UnitID                       1250
# UnitName                     1250
# UnitFlag                        2
# Municipality                  334
# CompletionDate              19970
# Agent                         929
# _Max`Prod`(BOE)             86073
# _Fracture`Stages              131
# _Open`Hole                      2
# _Completion`Events            305
# dtype: int64

# %%
# List of columns with too many null values: must be dropped
null_cols_to_drop = list(df_train.isnull().sum()[df_train.isnull().sum()>450000].index)
null_cols_to_drop
# Out:
# ['CurrentOperatorID',
#  'LicenseeID',
#  'UnitID',
#  'UnitName',
#  'Municipality',
#  'CompletionDate',
#  '_Fracture`Stages',
#  '_Completion`Events']

# %% [markdown]
# # Not important Columns to drop

# %% [markdown]
# - Cant drop any of the provinces because there is a good representation of them in the test dataset

# %%
df_train['Province'].value_counts()
# Out:
# Alberta             434043
# Saskatchewan        115815
# British Columbia     30278
# Manitoba              8537
# Name: Province, dtype: int64

# %%
df_clas_header_test['Province'].value_counts()
# Out:
# Alberta             86563
# Saskatchewan        23531
# British Columbia     6315
# Manitoba             1667
# Name: Province, dtype: int64

# %%
pd.unique(df_train['SurveySystem'])
# Out:
# array(['DLS', 'NTS'], dtype=object)

# %%
df_train['Province'][df_train['SurveySystem']=='NTS'].value_counts()
# Out:
# British Columbia    21478
# Name: Province, dtype: int64

# %%
df_clas_header_test['Province'][df_train['SurveySystem']=='NTS'].value_counts()
# Out:
# Alberta             3127
# Saskatchewan         837
# British Columbia     228
# Manitoba              66
# Name: Province, dtype: int64

# %% [markdown]
# # Colomns wit similarities to drop

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588673 entries, 0 to 588672
# Data columns (total 92 columns):
# EPAssetsId                 588673 non-null int64
# well_status                588673 non-null object
# well_status_code           588673 non-null int64
# Province                   588673 non-null object
# LicenceNumber              588673 non-null object
# UWI                        588673 non-null object
# CurrentOperator            588673 non-null object
# CurrentOperatorParent      588673 non-null int64
# CurrentOperatorID          124038 non-null float64
# Licensee                   588673 non-null object
# LicenseeParentCompany      588673 non-null int64
# LicenseeID                 8537 non-null float64
# LicenceDate                588664 non-null object
# WellType                   588673 non-null object
# WellTypeStandardised       588673 non-null object
# ConfidentialReleaseDate    310703 non-null object
# SurfAbandonDate            149148 non-null object
# WellName                   588206 non-null object
# WellNameAmended            588206 non-null object
# Formation                  588673 non-null object
# Field                      588673 non-null object
# Pool                       588442 non-null object
# SurveySystem               588673 non-null object
# Surf_Location              588366 non-null object
# Surf_Township              588673 non-null object
# Surf_Meridian              588673 non-null object
# Surf_Range                 588673 non-null object
# Surf_Section               588673 non-null object
# Surf_LSD                   588673 non-null object
# Surf_Longitude             588673 non-null float64
# Surf_Latitude              588673 non-null float64
# Surf_TownshipRange         588673 non-null object
# Surf_QuarterUnit           588673 non-null object
# Surf_Unit                  588673 non-null object
# Surf_Block                 588673 non-null object
# Surf_NTSMapSheet           588673 non-null object
# Surf_Series                588673 non-null object
# Surf_Area                  588673 non-null object
# Surf_Sheet                 588673 non-null object
# Surf_QuarterSection        588673 non-null object
# BH_Location                588673 non-null object
# BH_TownshipRange           588673 non-null object
# BH_QuarterUnit             588673 non-null object
# BH_Unit                    588673 non-null object
# BH_Block                   588673 non-null object
# BH_NTSMapSheet             588673 non-null object
# BH_Series                  588673 non-null object
# BH_Area                    588673 non-null object
# BH_Sheet                   588673 non-null object
# BH_QuarterSection          558395 non-null object
# BH_Longitude               555782 non-null float64
# BH_Latitude                555782 non-null float64
# BH_Township                588668 non-null object
# BH_Meridian                588673 non-null object
# BH_Range                   588668 non-null object
# BH_Section                 588668 non-null object
# BH_LSD                     588668 non-null object
# GroundElevation            588371 non-null float64
# KBElevation                579272 non-null float64
# TotalDepth                 582541 non-null float64
# LaheeClass                 588673 non-null object
# Confidential               588673 non-null object
# SurfaceOwner               577873 non-null object
# OSArea                     557634 non-null object
# OSDeposit                  557634 non-null object
# DrillingContractor         587108 non-null object
# SpudDate                   564917 non-null object
# FinalDrillDate             540114 non-null object
# RigReleaseDate             465455 non-null object
# DaysDrilling               563617 non-null float64
# DrillMetresPerDay          588630 non-null float64
# TVD                        552435 non-null float64
# WellProfile                588673 non-null object
# WellSymbPt1                588673 non-null object
# Country                    588673 non-null object
# RegulatoryAgency           588673 non-null object
# NumberofWells              588673 non-null int64
# PSACAreaCode               588673 non-null object
# PSACAreaName               588673 non-null object
# ProjectedDepth             404812 non-null float64
# StatusDate                 588603 non-null object
# StatusSource               588673 non-null object
# UnitID                     44299 non-null object
# UnitName                   44299 non-null object
# UnitFlag                   557380 non-null object
# Municipality               116651 non-null object
# CompletionDate             113144 non-null object
# Agent                      588673 non-null object
# _Max`Prod`(BOE)            187602 non-null float64
# _Fracture`Stages           7685 non-null float64
# _Open`Hole                 588673 non-null object
# _Completion`Events         16329 non-null float64
# dtypes: float64(16), int64(5), object(71)
# memory usage: 437.7+ MB

# %% [raw]
# # -*- coding: utf-8 -*-
# """
# ===================================
# Demo of DBSCAN clustering algorithm
# ===================================
#
# Finds core samples of high density and expands clusters from them.
#
# """
# print(__doc__)
#
# import numpy as np
#
# from sklearn.cluster import DBSCAN
# from sklearn import metrics
# from sklearn.datasets.samples_generator import make_blobs
# from sklearn.preprocessing import StandardScaler
#
#
# # #############################################################################
# # Generate sample data
# centers = [[1, 1], [-1, -1], [1, -1]]
# X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
#                             random_state=0)
#
# X = StandardScaler().fit_transform(X)
#
# # #############################################################################
# # Compute DBSCAN
# db = DBSCAN(eps=0.3, min_samples=10).fit(X)
# core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
# core_samples_mask[db.core_sample_indices_] = True
# labels = db.labels_
#
# # Number of clusters in labels, ignoring noise if present.
# n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
# n_noise_ = list(labels).count(-1)
#
# print('Estimated number of clusters: %d' % n_clusters_)
# print('Estimated number of noise points: %d' % n_noise_)
# print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
# print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
# print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
# print("Adjusted Rand Index: %0.3f"
#       % metrics.adjusted_rand_score(labels_true, labels))
# print("Adjusted Mutual Information: %0.3f"
#       % metrics.adjusted_mutual_info_score(labels_true, labels,
#                                            average_method='arithmetic'))
# print("Silhouette Coefficient: %0.3f"
#       % metrics.silhouette_score(X, labels))
#
# # #############################################################################
# # Plot result
# import matplotlib.pyplot as plt
#
# # Black removed and is used for noise instead.
# unique_labels = set(labels)
# colors = [plt.cm.Spectral(each)
#           for each in np.linspace(0, 1, len(unique_labels))]
# for k, col in zip(unique_labels, colors):
#     if k == -1:
#         # Black used for noise.
#         col = [0, 0, 0, 1]
#
#     class_member_mask = (labels == k)
#
#     xy = X[class_member_mask & core_samples_mask]
#     plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
#              markeredgecolor='k', markersize=14)
#
#     xy = X[class_member_mask & ~core_samples_mask]
#     plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
#              markeredgecolor='k', markersize=6)
#
# plt.title('Estimated number of clusters: %d' % n_clusters_)
# plt.show()

# %%
#pd.unique(df_train[df_train['well_status']=='Abandoned']['Municipality'])

# %%
#pd.unique(df_train[df_train['well_status']=='Active']['Municipality'])

# %%
useless_cols = ['UWI',
                'WellType',
 'ConfidentialReleaseDate',
 'WellName',
 'SurveySystem',
 'Surf_Location',
 'Surf_Township',
 'Surf_Meridian',
 'Surf_Range',
 'Surf_Section',
 'Surf_LSD',
 'Surf_Longitude',
 'Surf_Latitude',
 'Surf_TownshipRange',
 'Surf_QuarterUnit',
 'Surf_Unit',
 'Surf_Block',
 'Surf_NTSMapSheet',
 'Surf_Series',
 'Surf_Area',
 'Surf_Sheet',
 'Surf_QuarterSection',
 'BH_Location',
 'BH_TownshipRange',
 'BH_QuarterUnit',
 'BH_Unit',
 'BH_Block',
 'BH_NTSMapSheet',
 'BH_Series',
 'BH_Area',
 'BH_Sheet',
 'BH_QuarterSection',
 'BH_Longitude',
 'BH_Latitude',
 'BH_Township',
 'BH_Meridian',
 'BH_Range',
 'BH_Section',
 'BH_LSD',
 'GroundElevation',
 'KBElevation',
 'SurfaceOwner',
 'DrillingContractor',
 'SpudDate',
 'RigReleaseDate',
 'DaysDrilling',
 'DrillMetresPerDay',
 'Country',
 'RegulatoryAgency',
 'NumberofWells',
 'ProjectedDepth',
 'StatusSource',
 'UnitID',
 'UnitName',
 'UnitFlag',
 'Municipality',
 'CompletionDate',
 'Agent',
 '_Fracture`Stages',
 '_Completion`Events']
useless_cols[0],useless_cols[len(useless_cols)-1]
# Out:
# ('UWI', '_Completion`Events')

# %%
overlaping_cols_to_drop =[
 'CurrentOperator',
 'CurrentOperatorParent',
 'Licensee',
 'LicenseeParentCompany',
 'WellType',
 'WellName',
 'OSArea']

# %% [raw]
# df_test = pd.DataFrame(data=np.arange(92).reshape(1,92), columns=features_lst)
# df_test

# %% [raw]
# for i in range(len(overlaping_cols_to_drop)):
#     if overlaping_cols_to_drop[i] in list(df_test.columns):
#         df_test.drop(overlaping_cols_to_drop[i], axis = 1, inplace=True)
#
# for i in range(len(useless_cols)):
#     if useless_cols[i] in list(df_test.columns):
#         df_test.drop(useless_cols[i], axis = 1, inplace=True)
#
# for i in range(len(null_cols_to_drop)):
#     if null_cols_to_drop[i] in list(df_test.columns):
#         df_test.drop(null_cols_to_drop[i], axis = 1, inplace=True)
#
# df_test.info()

# %%
for i in range(len(overlaping_cols_to_drop)):
    if overlaping_cols_to_drop[i] in list(df_train.columns):
        df_train.drop(overlaping_cols_to_drop[i], axis = 1, inplace=True)

for i in range(len(useless_cols)):
    if useless_cols[i] in list(df_train.columns):
        df_train.drop(useless_cols[i], axis = 1, inplace=True)
        
for i in range(len(null_cols_to_drop)):
    if null_cols_to_drop[i] in list(df_train.columns):
        df_train.drop(null_cols_to_drop[i], axis = 1, inplace=True)
        
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588673 entries, 0 to 588672
# Data columns (total 25 columns):
# EPAssetsId              588673 non-null int64
# well_status             588673 non-null object
# well_status_code        588673 non-null int64
# Province                588673 non-null object
# LicenceNumber           588673 non-null object
# LicenceDate             588664 non-null object
# WellTypeStandardised    588673 non-null object
# SurfAbandonDate         149148 non-null object
# WellNameAmended         588206 non-null object
# Formation               588673 non-null object
# Field                   588673 non-null object
# Pool                    588442 non-null object
# TotalDepth              582541 non-null float64
# LaheeClass              588673 non-null object
# Confidential            588673 non-null object
# OSDeposit               557634 non-null object
# FinalDrillDate          540114 non-null object
# TVD                     552435 non-null float64
# WellProfile             588673 non-null object
# WellSymbPt1             588673 non-null object
# PSACAreaCode            588673 non-null object
# PSACAreaName            588673 non-null object
# StatusDate              588603 non-null object
# _Max`Prod`(BOE)         187602 non-null float64
# _Open`Hole              588673 non-null object
# dtypes: float64(3), int64(2), object(20)
# memory usage: 136.8+ MB

# %%
df_train['LicenceDate'] = pd.to_datetime(df_train['LicenceDate'].str.split(' ', 0).str[0])
df_train['SurfAbandonDate'] = pd.to_datetime(df_train['SurfAbandonDate'].str.split(' ', 0).str[0])
df_train['FinalDrillDate'] = pd.to_datetime(df_train['FinalDrillDate'].str.split(' ', 0).str[0])
df_train['StatusDate'] = pd.to_datetime(df_train['StatusDate'].str.split(' ', 0).str[0])

# %%
# calculating the number of days between getting the license and reporting the status
days_to_stat= df_train['StatusDate']-df_train['LicenceDate']
days_to_stat.isnull().sum()
# Out:
# 71

# %%
days_to_stat[days_to_stat<pd.Timedelta('0 days +00:00:00')] = np.nan
days_to_stat.isnull().sum()
# Out:
# 986

# %%
# Storing the number of days as a floating number in a new columns
df_train['Days_to_StatusDate'] = days_to_stat.dt.days

# %%
# Check to see if we have same number of null values before and after creating the column
days_to_stat.isnull().sum() , df_train['Days_to_StatusDate'].isnull().sum()
# Out:
# (986, 986)

# %%
df_train.replace('NaN',np.nan ,inplace=True)
df_train.replace('None',np.nan ,inplace=True)

# %%
df_train.head(5)
# Out:
#    EPAssetsId well_status  well_status_code          Province LicenceNumber  \
# 0     2314251   Suspended                 2           Alberta       0133238
# 1     2341273      Active                 1           Alberta       0419701
# 2     1086314   Abandoned                 0      Saskatchewan        11E153
# 3     2210835   Abandoned                 0           Alberta       0088786
# 4       40946   Suspended                 2  British Columbia         31827
#
#   LicenceDate WellTypeStandardised SurfAbandonDate  \
# 0  1988-03-22                  Gas             NaT
# 1  2010-04-09              Bitumen             NaT
# 2  2011-05-16                  Oil             NaT
# 3  1981-02-04                  Oil             NaT
# 4  2015-11-30          Unspecified             NaT
#
#                         WellNameAmended    Formation  \
# 0                 Cve Edson 12-18-49-16    Mannville
# 1            Cnrl 1b St. Paul 1-15-54-7         Dina
# 2           HUSKY WESTHAZEL A2-31-50-22    Paleozoic
# 3         Caltex_Res Provost 10-21-37-1  Unspecified
# 4  Leucrotta   Two Rivers  16-30-082-16  Unspecified
#
#                          Field                         Pool  TotalDepth  \
# 0                        Edson          Commingled Pool 017      3044.0
# 1                      Derwent           Lower Grand Rapids       785.0
# 2  Westhazel General Petroleum  Westhazel General Petroleum       621.0
# 3                      Provost            Upper Mannville A       830.0
# 4                  Other Areas                  Unspecified      1977.2
#
#     LaheeClass      Confidential           OSDeposit FinalDrillDate      TVD  \
# 0  Development  Non-Confidential      Not Applicable     1993-04-05  3044.00
# 1  Development  Non-Confidential  Lower Grand Rapids     2010-07-27   628.77
# 2  Development  Non-Confidential      Not Applicable     2011-08-24   621.00
# 3      Outpost  Non-Confidential      Not Applicable     1981-02-09   830.00
# 4      Outpost  Non-Confidential                 NaN            NaT      NaN
#
#    WellProfile WellSymbPt1 PSACAreaCode               PSACAreaName StatusDate  \
# 0     Vertical         Gas          AB2            Foothills Front 2003-12-01
# 1  Directional         Oil          AB4       East Central Alberta 2010-08-31
# 2     Vertical         Oil          SK1       Central Saskatchewan 2011-05-16
# 3     Vertical         Oil          AB4       East Central Alberta 1987-02-19
# 4     Vertical       Other          BC2  Northern British Columbia 2016-07-14
#
#    _Max`Prod`(BOE)      _Open`Hole  Days_to_StatusDate
# 0              NaN  CasedCompleted              5732.0
# 1         95.38271  CasedCompleted               144.0
# 2              NaN  CasedCompleted                 0.0
# 3              NaN  CasedCompleted              2206.0
# 4              NaN  CasedCompleted               227.0

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588673 entries, 0 to 588672
# Data columns (total 26 columns):
# EPAssetsId              588673 non-null int64
# well_status             588673 non-null object
# well_status_code        588673 non-null int64
# Province                588673 non-null object
# LicenceNumber           588673 non-null object
# LicenceDate             588664 non-null datetime64[ns]
# WellTypeStandardised    588673 non-null object
# SurfAbandonDate         149148 non-null datetime64[ns]
# WellNameAmended         588206 non-null object
# Formation               588673 non-null object
# Field                   588673 non-null object
# Pool                    588442 non-null object
# TotalDepth              582541 non-null float64
# LaheeClass              588673 non-null object
# Confidential            588673 non-null object
# OSDeposit               557634 non-null object
# FinalDrillDate          540114 non-null datetime64[ns]
# TVD                     552435 non-null float64
# WellProfile             588673 non-null object
# WellSymbPt1             588673 non-null object
# PSACAreaCode            588673 non-null object
# PSACAreaName            588673 non-null object
# StatusDate              588603 non-null datetime64[ns]
# _Max`Prod`(BOE)         187602 non-null float64
# _Open`Hole              588673 non-null object
# Days_to_StatusDate      587687 non-null float64
# dtypes: datetime64[ns](4), float64(4), int64(2), object(16)
# memory usage: 141.3+ MB

# %%
df_train.nunique()
# Out:
# EPAssetsId              588673
# well_status                  3
# well_status_code             3
# Province                     4
# LicenceNumber           485571
# LicenceDate              19975
# WellTypeStandardised        65
# SurfAbandonDate          22643
# WellNameAmended         471104
# Formation                  591
# Field                     1997
# Pool                     11028
# TotalDepth               25690
# LaheeClass                  17
# Confidential                 5
# OSDeposit                   13
# FinalDrillDate           27257
# TVD                      96613
# WellProfile                  5
# WellSymbPt1                  5
# PSACAreaCode                15
# PSACAreaName                15
# StatusDate               26245
# _Max`Prod`(BOE)          86073
# _Open`Hole                   2
# Days_to_StatusDate       20714
# dtype: int64

# %%
# univariate plots
fig1,axes=plt.subplots(nrows=1,ncols=1)
sns.countplot(df_train['well_status'], order = df_train.well_status.value_counts().
              index ,color = '0.5' )
plt.xticks(rotation = 90)
;
df_train['well_status'].value_counts()
# Out:
# Abandoned    248127
# Active       234232
# Suspended    106314
# Name: well_status, dtype: int64

# %%
# univariate plots
# doesnt seemto be a good classifier, especially considering there is a finer geographical 
# classifier in PSACArea parameters
# Leave it out.
fig1,axes=plt.subplots(nrows=1,ncols=1)
sns.countplot(df_train['Province'], order = df_train.Province.value_counts().
              index , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train[df_train['Province']=='Saskatchewan']['well_status'].value_counts()
# Out:
# Active       51302
# Abandoned    38722
# Suspended    25791
# Name: well_status, dtype: int64

# %%
# univariate plots
# looks like a great identifier for abandoned wells. If the LaheeClass != Developmet, 
# there is a 64% chance that the well is abandoned
# Use it!
fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['LaheeClass'], order = df_train.LaheeClass.value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train[df_train['LaheeClass']!='Development']['well_status'].value_counts()/(136095+41801+31947)
# Out:
# Abandoned    0.648556
# Active       0.199201
# Suspended    0.152242
# Name: well_status, dtype: float64

# %%
# univariate plots
# doesnt seem to be a good classifier. 
# leave it out
fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['Confidential'], order = df_train.Confidential.value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train[df_train['Confidential']!='Non-Confidential']['well_status'].value_counts()
# Out:
# Active       9954
# Abandoned    6451
# Suspended    1440
# Name: well_status, dtype: int64

# %%
# univariate plot
# OSDeposit desnt seem to be a good dummy variable. df_train['OSDeposit']!= Not Applicable has 
# too few data points. The difference in ratio of Abondoned vs Active for 2 major classes is not that
# large(data in the next 2 cells)
# leave it out!
fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['OSDeposit'], order = df_train.OSDeposit.value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train['OSDeposit'].value_counts()
# Out:
# Not Applicable          528084
# Wabiskaw-Mcmurray        10111
# Lower Grand Rapids        7836
# Clearwater                5966
# Upper Grand Rapids        4216
# Bluesky-Gething           1261
# Clearwater Undefined        93
# Grosmont                    36
# Pekisko Undefined           23
# Nisku                        3
# Middle Grand Rapids          3
# Belloy                       1
# Shunda                       1
# Name: OSDeposit, dtype: int64

# %%
df_train[df_train['OSDeposit']=='Not Applicable']['well_status'].value_counts()/(528084)
# Out:
# Abandoned    0.430000
# Active       0.395233
# Suspended    0.174768
# Name: well_status, dtype: float64

# %%
df_train[df_train['OSDeposit']!='Not Applicable']['well_status'].value_counts()/(588673-528084)
# Out:
# Active       0.421133
# Abandoned    0.347439
# Suspended    0.231428
# Name: well_status, dtype: float64

# %%
# univariate plots
# Awsome, probably need to drop last 2 categories, then use remaining 3 categories
# use it!
fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['WellProfile'], order = df_train.WellProfile.value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train['WellProfile'].value_counts()
# Out:
# Vertical          414139
# Directional        91827
# Horizontal         82592
# Horizontal Leg        69
# Slant                 46
# Name: WellProfile, dtype: int64

# %%
# univariate plots
# too good to dismiss. 
# Use it!

fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['WellSymbPt1'], order = df_train.WellSymbPt1.value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train['WellSymbPt1'].value_counts()
# Out:
# Other        199821
# Gas          190117
# Oil          178375
# Injection     20356
# Oil & Gas         4
# Name: WellSymbPt1, dtype: int64

# %%
# univariate plots
# would be awsome to use all the categories as opposed to 0-1 dummies
# regardless, use it!

fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['PSACAreaCode'], order = df_train.PSACAreaCode.value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train['PSACAreaCode'].value_counts()
# Out:
# AB3    134944
# AB5     71561
# AB6     66792
# AB2     57989
# AB4     55351
# SK2     47632
# AB7     44662
# SK1     34430
# SK3     33753
# BC2     29852
# MB       8537
# AB1      2744
# BC1       318
# BC0        77
# BC3        31
# Name: PSACAreaCode, dtype: int64

# %%
# univariate plots
# same as 'PSACAreaCode'.
# Drop it.
fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['PSACAreaName'], order = df_train.PSACAreaName.value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
df_train['PSACAreaName'].value_counts()
# Out:
# Southeastern Alberta         134944
# Central Alberta               71561
# Northeastern Alberta          66792
# Foothills Front               57989
# East Central Alberta          55351
# Southwestern Saskatchewan     47632
# Northwestern Alberta          44662
# Central Saskatchewan          34430
# Eastern Saskatchewan          33753
# Northern British Columbia     29852
# Manitoba                       8537
# Foothills                      2744
# Southern British Columbia       318
# Other British Columbia           77
# Coastal British Columbia         31
# Name: PSACAreaName, dtype: int64

# %%
# univariate plots
# Not good!
# leave it out.
fig1,axes=plt.subplots(nrows=1,ncols=1,dpi=150)
sns.countplot(df_train['_Open`Hole'], order = df_train['_Open`Hole'].value_counts().
              index  , hue=df_train['well_status'])
plt.xticks(rotation = 90)
;
# Out:
# ''

# %%
df_train['_Open`Hole'].value_counts()
# Out:
# CasedCompleted    583755
# Open Hole           4918
# Name: _Open`Hole, dtype: int64

# %%
# Total Depth may be a usefull parameter. Further investigate. 
corr = df_train.corr()
plt.figure(figsize=(9,7))
sns.heatmap(
    corr,
    xticklabels=corr.columns.values,
    yticklabels=corr.columns.values,
    linecolor='white',
    linewidths=0.1,
    cmap="RdBu"
)
plt.show()

# %%
# License number is alpha numerical, can't include it in prediction
# Leave it out.
df_train['LicenceNumber'].sample(10)
# Out:
# 84673     0214351
# 141987    0383461
# 104396    0188487
# 411597    0161105
# 52928     0325061
# 211596      11016
# 247349    0400426
# 87483     0295097
# 128397    0151552
# 321521    0335635
# Name: LicenceNumber, dtype: object

# %%
# seems that almost all the wells with an existing SurfAbandonDate are abandoned
# Use it.

df_train[df_train['SurfAbandonDate'].notna()]['well_status'].value_counts()
# Out:
# Abandoned    147774
# Suspended       853
# Active          521
# Name: well_status, dtype: int64

# %%
# it seems a large portion of abondoned wells (50% +) belong to "Unspecified" Pool category, while it has 
# a smaller role in suspended wells and even smaller one for Active wells. 
# considering more than 11,000 pool types, "Pool == Unspecified" should simplify this and 
# create a good dummy variable
# create and Use 'Pool' dummy as stated above


#---------------------
# Similar but much weaker relationship exists for Unspecified Formation. But to avoid inter-relationship between
# features, it is should not be considered
# Leave "Formation" out.
#--------------------
# Same strong relationship doesnt exist for Field names
# Leave "Field" out.


df_train[df_train['well_status']=='Abandoned']['Pool'].value_counts()/248127
# Out:
# Unspecified                 0.545696
# Not Available               0.041684
# Commingled MFP9501          0.025092
# Commingled Pool 001         0.011514
# Lower Grand Rapids          0.010543
#                               ...
# Cummings WW                 0.000004
# Sulphur Point LLL           0.000004
# Cadomin B-089-B/094-B-08    0.000004
# Fort Pitt North Waseca      0.000004
# Upper Mannville D6D         0.000004
# Name: Pool, Length: 7223, dtype: float64

# %%
df_train[df_train['well_status']=='Active']['Pool'].value_counts()/234232
# Out:
# Commingled MFP9501     0.253667
# Unspecified            0.056252
# Commingled MFP9529     0.026431
# Wabiskaw-Mcmurray      0.026282
# Commingled Pool 001    0.025398
#                          ...
# Grand Rapids WW        0.000004
# Bluesky KKK            0.000004
# Viking P9P             0.000004
# Falher EE              0.000004
# Upper Mannville D6D    0.000004
# Name: Pool, Length: 6171, dtype: float64

# %%
df_train[df_train['well_status']=='Suspended']['Pool'].value_counts()/106314
# Out:
# Unspecified            0.187087
# Commingled MFP9501     0.040418
# Commingled Pool 001    0.029479
# Lower Grand Rapids     0.028463
# Upper Grand Rapids     0.018963
#                          ...
# Mattson G              0.000009
# Kiskatinaw P           0.000009
# Halfway XX             0.000009
# Slave Point EEE        0.000009
# Grand Rapids Z6Z       0.000009
# Name: Pool, Length: 6318, dtype: float64

# %%
# Seem extremely small TVD depth is associated with increased chance of having an abondoned well, 
# however larger TVDs dont shift the results one way or another
# it is difficult to see how this can help prediction
# test to see if it helps. 
df_train[df_train['TVD']<450]['well_status'].value_counts()/(48426+19728+7410)
# Out:
# Abandoned    0.640861
# Active       0.261077
# Suspended    0.098063
# Name: well_status, dtype: float64

# %%
# Seem extremely smaller well depth is associated with increased chance of having an abondoned well, while
# relatively large well depth increases chance of having an active well.
# this might overlap with having a horizontal well
# regardless, this may be one of the input features. 
# Test to see if it helps

df_train[df_train['TotalDepth']<530]['well_status'].value_counts()
# Out:
# Abandoned    64469
# Active       30580
# Suspended    12094
# Name: well_status, dtype: int64

# %%
df_train.describe()
# Out:
#          EPAssetsId  well_status_code     TotalDepth            TVD  \
# count  5.886730e+05     588673.000000  582541.000000  552435.000000
# mean   2.019055e+06          0.759097    1219.381771    1034.012322
# std    9.069427e+05          0.737610     925.750194     732.708950
# min    1.000000e+00          0.000000       0.000000       0.000000
# 25%    2.001535e+06          0.000000     592.500000     554.000000
# 50%    2.210924e+06          1.000000     940.000000     804.000000
# 75%    2.420443e+06          1.000000    1621.300000    1348.700000
# max    7.012320e+06          2.000000   39867.000000    6803.000000
#
#        _Max`Prod`(BOE)  Days_to_StatusDate  HorizontalLegnth
# count    187602.000000       587687.000000     552384.000000
# mean         65.415357         2251.789398        159.360578
# std         244.694592         3878.477896        436.578723
# min           0.019619            0.000000      -4879.000000
# 25%           3.019104           17.000000          0.000000
# 50%           9.358422          198.000000          0.000000
# 75%          33.720639         3150.000000         13.462500
# max       20177.542605        29620.000000      37603.400000

# %%
# Scatter plot of Loan Amount on Monthly Payments,for different loan Terms
df_train['HorizontalLegnth'] =  df_train['TotalDepth']-df_train['TVD']

sns.scatterplot(y='HorizontalLegnth',x='''_Max`Prod`(BOE)''',data=df_train[df_train['well_status']=='Abandoned'], 
           hue = 'WellProfile')



#   axis name for the boxplot
#plt.='''Original Loan Amount(USD)''')
#axes.set(ylabel='Monthly Loan Payment (USD)')
plt.ylim(0,5000)
plt.xlim(0,5000);
#plt.title('''Effect of Loan Amount(USD) on Monthly Payments(USD), 
#for different loan Terms(months)'''.title(), fontsize = 14, weight = 'bold');

# %%
# Scatter plot of Loan Amount on Monthly Payments,for different loan Terms
df_train['HorizontalLegnth'] =  df_train['TotalDepth']-df_train['TVD']

sns.scatterplot(y='HorizontalLegnth',x='''well_status''',data=df_train, 
           hue = 'WellProfile')



#   axis name for the boxplot
#plt.='''Original Loan Amount(USD)''')
#axes.set(ylabel='Monthly Loan Payment (USD)')
plt.ylim(0,5000)
#plt.xlim(0,5000);
#plt.title('''Effect of Loan Amount(USD) on Monthly Payments(USD), 
#for different loan Terms(months)'''.title(), fontsize = 14, weight = 'bold');
# Out:
# (0, 5000)

# %%
# LoanOriginalAmount variation for each ProsperRating (numeric) category


sns.boxplot(data=df_train, y='well_status', x='HorizontalLegnth', color='0.5')




#   axis name for the boxplot
axes.set(ylabel='''Prosper Credit Rating("AA" is the Best, "E" is the Worst)''')
axes.set(xlabel='Loan Original Amount(USD)')
plt.xlim(-1000,10000);

# %%
# the effect of Days_to_StatusDate on well status does not seem to be linear. It also seems that it needs 
# more than 2 bins to help with classification
# To include it, we may need some classification work or hyper parameter tuning
# Test to see if it helps

df_train[df_train['Days_to_StatusDate']>80]['well_status'].value_counts()
# Out:
# Active       154013
# Abandoned    134785
# Suspended     66741
# Name: well_status, dtype: int64

# %%
# _Max`Prod`(BOE) seems to be great for identifying Active wells
# _Max`Prod`(BOE) notnull can be a great dummy variable to help identifying Active wells
# use it, but pleaeaeaease change the name!
df_train[df_train['''_Max`Prod`(BOE)''']>0]['well_status'].value_counts()/187602
# Out:
# Active       0.860295
# Suspended    0.120478
# Abandoned    0.019227
# Name: well_status, dtype: float64

# %%
161393+22602+3607
# Out:
# 187602

# %% [markdown]
# # Create Dummies
# - Hot encoding or not?

# %%
df_train_processed = df_train.copy()

# %%
df_train_processed['''_Max`Prod`(BOE)'''].where(df_train_processed['''_Max`Prod`(BOE)'''].isnull(), 1).where(df_train_processed['''_Max`Prod`(BOE)'''].notnull(), 0).sum()
# Out:
# 187602.0

# %%
df_train_processed['''_Max`Prod`(BOE)'''] = df_train_processed['''_Max`Prod`(BOE)'''].where(df_train_processed['''_Max`Prod`(BOE)'''].isnull(), 1).where(df_train_processed['''_Max`Prod`(BOE)'''].notnull(), 0)

# %%
df_train_processed['SurfAbandonDate'] = df_train_processed['SurfAbandonDate'].where(df_train_processed['SurfAbandonDate'].isnull(), 1).where(df_train_processed['SurfAbandonDate'].notnull(), 0)

# %%
df_train_processed.sample(10)
# Out:
#         EPAssetsId well_status  well_status_code      Province LicenceNumber  \
# 323121     2200647   Suspended                 2       Alberta       0337085
# 408165     2332340   Abandoned                 0       Alberta      I0000001
# 334178     1130794      Active                 1  Saskatchewan        86J049
# 260886     1145600      Active                 1  Saskatchewan        14A382
# 159228     2377074      Active                 1       Alberta       0311167
# 554528     2282981   Suspended                 2       Alberta       0287481
# 537449     2223749      Active                 1       Alberta       0113851
# 567310     2251389      Active                 1       Alberta       0313615
# 293505     2201335   Abandoned                 0       Alberta       0236431
# 168807     2564620   Abandoned                 0       Alberta       0094005
#
#        LicenceDate WellTypeStandardised SurfAbandonDate  \
# 323121  2005-08-25          Unspecified               0
# 408165  1949-08-23          Unspecified               0
# 334178  1986-10-24                  Gas               0
# 260886  2014-01-27                  Oil               0
# 159228  2004-07-02                  Gas               0
# 554528  2003-05-23                  Gas               0
# 537449  1985-03-08                  Oil               0
# 567310  2004-08-19      Coalbed Methane               0
# 293505  2000-04-25                  Gas               0
# 168807  1981-12-18          Unspecified               1
#
#                              WellNameAmended         Formation  \
# 323121              Long Run Rich 4-14-35-22       Belly River
# 408165        Pan Western West Edmonton No.2       Unspecified
# 334178           NCO ET AL HATTON 8-31-15-28    Colorado Group
# 260886  TEINE PLATO N HZ 6D3-17-3D1-17-26-18  Viking Formation
# 159228                Cve Whcourt 4-30-58-11           Nordegg
# 554528           Velvet  Vik-Kins 6-12-46-11             Nisku
# 537449                 Nal Joffre 4-25-38-26          Joli Fou
# 567310             Ember Chigwell 1-14-41-24       Belly River
# 293505           Ember 102 Huxley 6-23-35-24          Lea Park
# 168807            Pex Adamsldg Ev 6-26-108-9       Unspecified
#
#                   Field                 Pool  TotalDepth         LaheeClass  \
# 323121             Rich          Unspecified       582.0   New Pool Wildcat
# 408165     Acheson East          Unspecified      1642.6  New Field Wildcat
# 334178           Hatton    Hatton Milk River       496.0        Development
# 260886      Plato North   Plato North Viking      1498.0        Development
# 159228       Whitecourt           Jurassic R      1765.0        Development
# 554528  Viking-Kinsella  Commingled Pool 021       843.4   Deeper Pool Test
# 537449           Joffre               Viking      1554.5        Development
# 567310         Chigwell   Edmonton Undefined       913.0        Development
# 293505           Huxley   Commingled MFP9501       957.0            Outpost
# 168807        Undefined          Unspecified       192.0  New Field Wildcat
#
#             Confidential       OSDeposit FinalDrillDate      TVD  WellProfile  \
# 323121  Non-Confidential  Not Applicable     2005-09-27   582.00     Vertical
# 408165  Non-Confidential  Not Applicable     1949-10-10  1642.60     Vertical
# 334178  Non-Confidential  Not Applicable     1986-10-30   496.00     Vertical
# 260886  Non-Confidential  Not Applicable     2014-02-15   682.80   Horizontal
# 159228  Non-Confidential  Not Applicable     2004-07-29  1748.24  Directional
# 554528  Non-Confidential  Not Applicable     2003-06-14   843.40     Vertical
# 537449  Non-Confidential  Not Applicable     1985-05-27  1554.50     Vertical
# 567310  Non-Confidential  Not Applicable     2004-11-05   520.81  Directional
# 293505  Non-Confidential  Not Applicable     2000-05-15   957.00     Vertical
# 168807  Non-Confidential  Not Applicable     1982-01-02   192.00     Vertical
#
#        WellSymbPt1 PSACAreaCode               PSACAreaName StatusDate  \
# 323121       Other          AB5            Central Alberta 2005-09-27
# 408165       Other          AB5            Central Alberta 1949-10-13
# 334178         Gas          SK2  Southwestern Saskatchewan 1986-10-24
# 260886         Oil          SK2  Southwestern Saskatchewan 2014-01-27
# 159228         Gas          AB5            Central Alberta 2005-01-01
# 554528         Gas          AB4       East Central Alberta 2012-12-01
# 537449         Oil          AB5            Central Alberta 2013-10-15
# 567310         Gas          AB5            Central Alberta 2004-11-26
# 293505         Gas          AB5            Central Alberta 2004-07-13
# 168807       Other          AB7       Northwestern Alberta 1982-01-03
#
#         _Max`Prod`(BOE)      _Open`Hole  Days_to_StatusDate
# 323121              0.0  CasedCompleted                33.0
# 408165              0.0  CasedCompleted                51.0
# 334178              1.0  CasedCompleted                 0.0
# 260886              1.0  CasedCompleted                 0.0
# 159228              1.0  CasedCompleted               183.0
# 554528              0.0  CasedCompleted              3480.0
# 537449              1.0  CasedCompleted             10448.0
# 567310              1.0  CasedCompleted                99.0
# 293505              0.0  CasedCompleted              1540.0
# 168807              0.0  CasedCompleted                16.0

# %%
df_train_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 588673 entries, 0 to 588672
# Data columns (total 26 columns):
# EPAssetsId              588673 non-null int64
# well_status             588673 non-null object
# well_status_code        588673 non-null int64
# Province                588673 non-null object
# LicenceNumber           588673 non-null object
# LicenceDate             588664 non-null datetime64[ns]
# WellTypeStandardised    588673 non-null object
# SurfAbandonDate         588673 non-null object
# WellNameAmended         588206 non-null object
# Formation               588673 non-null object
# Field                   588673 non-null object
# Pool                    588442 non-null object
# TotalDepth              582541 non-null float64
# LaheeClass              588673 non-null object
# Confidential            588673 non-null object
# OSDeposit               557634 non-null object
# FinalDrillDate          540114 non-null datetime64[ns]
# TVD                     552435 non-null float64
# WellProfile             588673 non-null object
# WellSymbPt1             588673 non-null object
# PSACAreaCode            588673 non-null object
# PSACAreaName            588673 non-null object
# StatusDate              588603 non-null datetime64[ns]
# _Max`Prod`(BOE)         588673 non-null float64
# _Open`Hole              588673 non-null object
# Days_to_StatusDate      587687 non-null float64
# dtypes: datetime64[ns](3), float64(4), int64(2), object(17)
# memory usage: 121.3+ MB

# %% [markdown]
# # ML
# - Include only the approved features: `WellTypeStandardised`,`LaheeClass`,`WellProfile`, `WellSymbPt1`, `SurfAbandonDate` , `Pool` and  `_Max'Prod'(BOE)`
# - Once the model was tuned, add `Days_to_StatusDate`, `TVD` and `Depth` to see if they improve
